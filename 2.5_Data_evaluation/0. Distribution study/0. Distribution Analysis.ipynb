# %% [markdown]
# # <center><b><h1> Distribution Analysis </h1></b></center>
#
# <p>Here we will study the distribution of the regions (148) , for each label (2) , for each feature (4).</p>
# <p>For do that we will apply:</p>
# <ol>
#     <li>
#     Anderson_darling test, wich will tell us if the distribution of a
#     region is normal (parametric, Gauss-Bell) or non parametric for each label. The possible results are:
#         <ul>
#             <li>
#                 The region x in the label A is normal as the region x in the label b,
#                 (label a = strong, label b = weak), if is normal in both we can make an hypothesis that
#                 this region for both labels has a normal distribution.
#                 <br><br>
#                 If the region has a normal distribution in the two label, we will apply a two-samples t-test
#                 for evaluate how much different are (the distribution of the region x in both labels).
#             </li>
#         </ul>
#         <ul>
#             <li>
#                 if the region x in the label a is normal but in the label b is not normal,
#                 (remember that normal is about the distribution) or vice versa,
#                 <br><br>
#                 them we will report this result to decide the next step.
#             </li>
#         </ul>
#         <ul>
#             <li>
#                 otherwise if the region x in both labels has not  a normal distribution
#                 (not parametric distribution) we will made a nonparametric test
#                 or Mann-Whitney to know how much diferent are
#                 the distributions of the same region in the two labels
#             </li>
#         </ul>
#     </li>
#     <li>
#          for the parametrics and not parametric regions (in both labels) we will made a graph
#     </li>
# </ol>

# %%
import pandas as pd

import matplotlib.pyplot as plt
from matplotlib.figure import Figure
import seaborn as sns
sns.set(color_codes=True)
from matplotlib.backends.backend_pdf import PdfPages

from scipy import stats
import numpy as np

from scipy.stats import ttest_ind, ttest_ind_from_stats
from scipy.special import stdtr


PATH_DATASETS = "../../2_Data_preparation/1_Compute_raw_datasets/output/"
PATH_OUTPUT =  "output/"

# %%
def readCsvs():
    datasets = []
    constant = '_Classified'
    features = ['area', 'meancurv', 'thickness', 'volume']

    for feature in features:
        df = pd.read_csv(PATH_DATASETS + feature + constant+ '.csv', index_col=0)
        datasets.append({'name': feature, 'data': df})
    return datasets

# %%
def isNormal(anderson_stat, critical_values, significance_levels):
    #h0 the distribution is normal
    result = {'normal': 1, 'significance': 0}

    for critical_value, significance_level in zip(critical_values, significance_levels):
        if anderson_stat > critical_value:
            # not is normal with a significance level of: 
            result['normal'] = 0
            result['significance'] = significance_level
        else:
            break
            
    return result

# %% [markdown]
# # 1. Prepare the data

# %%
Datasets = readCsvs() #Area,MeanCurv,Thickness,Volume

# %%
print(Datasets[0]['data'].shape)
Datasets[1]['data'].head()
# Out:
# (1108, 149)
#          lh_G_and_S_frontomargin_meancurv  lh_G_and_S_occipital_inf_meancurv  \
# Subject
# 100206                              0.177                              0.165
# 100307                              0.173                              0.150
# 100408                              0.167                              0.173
# 100610                              0.138                              0.153
# 101006                              0.152                              0.155
#
#          lh_G_and_S_paracentral_meancurv  lh_G_and_S_subcentral_meancurv  \
# Subject
# 100206                             0.144                           0.178
# 100307                             0.132                           0.183
# 100408                             0.137                           0.166
# 100610                             0.116                           0.139
# 101006                             0.121                           0.153
#
#          lh_G_and_S_transv_frontopol_meancurv  lh_G_and_S_cingul-Ant_meancurv  \
# Subject
# 100206                                  0.198                           0.160
# 100307                                  0.218                           0.175
# 100408                                  0.180                           0.169
# 100610                                  0.157                           0.133
# 101006                                  0.179                           0.157
#
#          lh_G_and_S_cingul-Mid-Ant_meancurv  \
# Subject
# 100206                                0.170
# 100307                                0.157
# 100408                                0.169
# 100610                                0.151
# 101006                                0.138
#
#          lh_G_and_S_cingul-Mid-Post_meancurv  \
# Subject
# 100206                                 0.171
# 100307                                 0.160
# 100408                                 0.179
# 100610                                 0.154
# 101006                                 0.131
#
#          lh_G_cingul-Post-dorsal_meancurv  lh_G_cingul-Post-ventral_meancurv  \
# Subject
# 100206                              0.219                              0.217
# 100307                              0.243                              0.198
# 100408                              0.241                              0.178
# 100610                              0.196                              0.163
# 101006                              0.202                              0.175
#
#          ...  rh_S_pericallosal_meancurv  rh_S_postcentral_meancurv  \
# Subject  ...
# 100206   ...                       0.175                      0.128
# 100307   ...                       0.188                      0.152
# 100408   ...                       0.173                      0.132
# 100610   ...                       0.161                      0.125
# 101006   ...                       0.122                      0.109
#
#          rh_S_precentral-inf-part_meancurv  rh_S_precentral-sup-part_meancurv  \
# Subject
# 100206                               0.145                              0.137
# 100307                               0.123                              0.125
# 100408                               0.142                              0.116
# 100610                               0.115                              0.119
# 101006                               0.118                              0.112
#
#          rh_S_suborbital_meancurv  rh_S_subparietal_meancurv  \
# Subject
# 100206                      0.152                      0.159
# 100307                      0.157                      0.152
# 100408                      0.139                      0.177
# 100610                      0.139                      0.131
# 101006                      0.166                      0.160
#
#          rh_S_temporal_inf_meancurv  rh_S_temporal_sup_meancurv  \
# Subject
# 100206                        0.136                       0.136
# 100307                        0.144                       0.137
# 100408                        0.131                       0.131
# 100610                        0.114                       0.122
# 101006                        0.135                       0.126
#
#          rh_S_temporal_transverse_meancurv  class
# Subject
# 100206                               0.156    1.0
# 100307                               0.147   -1.0
# 100408                               0.137    1.0
# 100610                               0.145    1.0
# 101006                               0.135    1.0
#
# [5 rows x 149 columns]

# %%
class_1 = 0
class_2 = 0
results_anderson_strong = []
results_anderson_weak = []

for dataset in Datasets:
    name = dataset['name']
    data = dataset['data']
    
    # copy all the subjects that belongs to the class 1 and -1 respectively
    # remember that class is a colum  in the end of the raw dataset classified
    class_1 = data[data['class'] == 1].copy()  
    class_2 = data[data['class'] == -1].copy()
    
    # the [:-1] is ommit the last character, in this case ommit the last colum that in this case is the column Class
    # you can print this and see the last part of each print to compare. 
    #print(df.columns.values)
    #print('\n')
    #print(df_stat.columns.values)
    
    df_anderson_strong = pd.DataFrame(columns=('region', 'anderson stat', 'critical values', 'significance level'))
    df_anderson_strong['region'] = data.columns.values[:-1]
    df_anderson_strong.set_index('region', inplace=True)
    
    df_anderson_weak = pd.DataFrame(columns=('region', 'anderson stat', 'critical values', 'significance level'))
    df_anderson_weak['region'] = data.columns.values[:-1]
    df_anderson_weak.set_index('region', inplace=True)
    
    for column in data.columns.values[:-1]:
        df_anderson_strong.at[column, 'anderson stat'], df_anderson_strong.at[column, 'critical values'],  df_anderson_strong.at[column, 'significance level'] = stats.anderson(class_1[column], dist = 'norm')
        
        df_anderson_weak.at[column, 'anderson stat'], df_anderson_weak.at[column, 'critical values'], df_anderson_weak.at[column, 'significance level'] = stats.anderson(class_2[column], dist = 'norm')

    results_anderson_strong.append({'name': name, 'data': df_anderson_strong})
    results_anderson_weak.append({'name': name, 'data': df_anderson_weak})

# %%
print("This is with the label strong")
results_anderson_strong[0]['data']
# Out:
# This is with the label strong
#                                  anderson stat  \
# region
# lh_G_and_S_frontomargin_area          0.472016
# lh_G_and_S_occipital_inf_area         0.491466
# lh_G_and_S_paracentral_area            1.89195
# lh_G_and_S_subcentral_area            0.908611
# lh_G_and_S_transv_frontopol_area      0.232544
# ...                                        ...
# rh_S_suborbital_area                   0.54585
# rh_S_subparietal_area                  5.17321
# rh_S_temporal_inf_area                0.208243
# rh_S_temporal_sup_area                0.324439
# rh_S_temporal_transverse_area         0.288901
#
#                                                       critical values  \
# region
# lh_G_and_S_frontomargin_area      [0.572, 0.651, 0.781, 0.911, 1.084]
# lh_G_and_S_occipital_inf_area     [0.572, 0.651, 0.781, 0.911, 1.084]
# lh_G_and_S_paracentral_area       [0.572, 0.651, 0.781, 0.911, 1.084]
# lh_G_and_S_subcentral_area        [0.572, 0.651, 0.781, 0.911, 1.084]
# lh_G_and_S_transv_frontopol_area  [0.572, 0.651, 0.781, 0.911, 1.084]
# ...                                                               ...
# rh_S_suborbital_area              [0.572, 0.651, 0.781, 0.911, 1.084]
# rh_S_subparietal_area             [0.572, 0.651, 0.781, 0.911, 1.084]
# rh_S_temporal_inf_area            [0.572, 0.651, 0.781, 0.911, 1.084]
# rh_S_temporal_sup_area            [0.572, 0.651, 0.781, 0.911, 1.084]
# rh_S_temporal_transverse_area     [0.572, 0.651, 0.781, 0.911, 1.084]
#
#                                            significance level
# region
# lh_G_and_S_frontomargin_area      [15.0, 10.0, 5.0, 2.5, 1.0]
# lh_G_and_S_occipital_inf_area     [15.0, 10.0, 5.0, 2.5, 1.0]
# lh_G_and_S_paracentral_area       [15.0, 10.0, 5.0, 2.5, 1.0]
# lh_G_and_S_subcentral_area        [15.0, 10.0, 5.0, 2.5, 1.0]
# lh_G_and_S_transv_frontopol_area  [15.0, 10.0, 5.0, 2.5, 1.0]
# ...                                                       ...
# rh_S_suborbital_area              [15.0, 10.0, 5.0, 2.5, 1.0]
# rh_S_subparietal_area             [15.0, 10.0, 5.0, 2.5, 1.0]
# rh_S_temporal_inf_area            [15.0, 10.0, 5.0, 2.5, 1.0]
# rh_S_temporal_sup_area            [15.0, 10.0, 5.0, 2.5, 1.0]
# rh_S_temporal_transverse_area     [15.0, 10.0, 5.0, 2.5, 1.0]
#
# [148 rows x 3 columns]

# %%
print("This is with the label weak")
results_anderson_weak[0]['data']
# Out:
# This is with the label weak
#                                  anderson stat  \
# region
# lh_G_and_S_frontomargin_area          0.548405
# lh_G_and_S_occipital_inf_area          1.01914
# lh_G_and_S_paracentral_area            2.86747
# lh_G_and_S_subcentral_area             1.92331
# lh_G_and_S_transv_frontopol_area       1.74058
# ...                                        ...
# rh_S_suborbital_area                  0.764867
# rh_S_subparietal_area                  4.22859
# rh_S_temporal_inf_area                0.822603
# rh_S_temporal_sup_area                 0.64061
# rh_S_temporal_transverse_area         0.208605
#
#                                                       critical values  \
# region
# lh_G_and_S_frontomargin_area      [0.572, 0.651, 0.781, 0.912, 1.084]
# lh_G_and_S_occipital_inf_area     [0.572, 0.651, 0.781, 0.912, 1.084]
# lh_G_and_S_paracentral_area       [0.572, 0.651, 0.781, 0.912, 1.084]
# lh_G_and_S_subcentral_area        [0.572, 0.651, 0.781, 0.912, 1.084]
# lh_G_and_S_transv_frontopol_area  [0.572, 0.651, 0.781, 0.912, 1.084]
# ...                                                               ...
# rh_S_suborbital_area              [0.572, 0.651, 0.781, 0.912, 1.084]
# rh_S_subparietal_area             [0.572, 0.651, 0.781, 0.912, 1.084]
# rh_S_temporal_inf_area            [0.572, 0.651, 0.781, 0.912, 1.084]
# rh_S_temporal_sup_area            [0.572, 0.651, 0.781, 0.912, 1.084]
# rh_S_temporal_transverse_area     [0.572, 0.651, 0.781, 0.912, 1.084]
#
#                                            significance level
# region
# lh_G_and_S_frontomargin_area      [15.0, 10.0, 5.0, 2.5, 1.0]
# lh_G_and_S_occipital_inf_area     [15.0, 10.0, 5.0, 2.5, 1.0]
# lh_G_and_S_paracentral_area       [15.0, 10.0, 5.0, 2.5, 1.0]
# lh_G_and_S_subcentral_area        [15.0, 10.0, 5.0, 2.5, 1.0]
# lh_G_and_S_transv_frontopol_area  [15.0, 10.0, 5.0, 2.5, 1.0]
# ...                                                       ...
# rh_S_suborbital_area              [15.0, 10.0, 5.0, 2.5, 1.0]
# rh_S_subparietal_area             [15.0, 10.0, 5.0, 2.5, 1.0]
# rh_S_temporal_inf_area            [15.0, 10.0, 5.0, 2.5, 1.0]
# rh_S_temporal_sup_area            [15.0, 10.0, 5.0, 2.5, 1.0]
# rh_S_temporal_transverse_area     [15.0, 10.0, 5.0, 2.5, 1.0]
#
# [148 rows x 3 columns]

# %%
results_anderson = []
for strong_result, weak_result in zip(results_anderson_strong, results_anderson_weak):
    
    name = strong_result['name']
    
    result_anderson = pd.DataFrame(columns=('region', 'normal in strong', 'normal in weak', 'normal in both'))
    result_anderson['region'] = strong_result['data'].index.values
    result_anderson.set_index('region', inplace=True)
    
    for column in strong_result['data'].index.values:
        Anderson_stat_strong = strong_result['data'].at[column, 'anderson stat']
        Anderson_stat_weak = weak_result['data'].at[column, 'anderson stat']
        
        critical_values_strong = strong_result['data'].at[column, 'critical values']
        critical_values_weak = weak_result['data'].at[column, 'critical values']
        
        significance_values = strong_result['data'].at[column, 'significance level']
        
        
        normal_strong = isNormal(Anderson_stat_strong, critical_values_strong, significance_values)
        if normal_strong['normal']:
            result_anderson.at[column, 'normal in strong'] = 1
        else:
            result_anderson.at[column, 'normal in strong'] = [0,normal_strong['significance']]
            
        normal_weak = isNormal(Anderson_stat_weak, critical_values_weak, significance_values)
        
        if normal_weak['normal']:
            result_anderson.at[column, 'normal in weak'] = 1
        else:
            result_anderson.at[column, 'normal in weak'] = [0, normal_weak['significance']]
            
            
        if normal_weak['normal'] and normal_strong['normal']:
            result_anderson.at[column, 'normal in both'] = 1
        else:
            result_anderson.at[column, 'normal in both'] = 0
            
    results_anderson.append(result_anderson)

# %% [markdown]
# <h3>Anderson result test for nomality</h3>
# <p>
#   whit this test we have classified each distribution, remember that each region has 2 distributions, one for each label.
# </p>
# <p>
#     1 = means normal, actually, the H0 of this test is that the distribution is normal. <br>
#     0 = means not normal, and the other value is the significance level.
# </p>

# %%
results_anderson[3]
# Out:
#                                    normal in strong normal in weak  \
# region
# lh_G_and_S_frontomargin_volume                    1              1
# lh_G_and_S_occipital_inf_volume            [0, 5.0]       [0, 1.0]
# lh_G_and_S_paracentral_volume              [0, 1.0]       [0, 1.0]
# lh_G_and_S_subcentral_volume               [0, 1.0]       [0, 1.0]
# lh_G_and_S_transv_frontopol_volume         [0, 1.0]       [0, 1.0]
# ...                                             ...            ...
# rh_S_suborbital_volume                     [0, 1.0]       [0, 1.0]
# rh_S_subparietal_volume                    [0, 1.0]       [0, 1.0]
# rh_S_temporal_inf_volume                          1       [0, 2.5]
# rh_S_temporal_sup_volume                          1       [0, 2.5]
# rh_S_temporal_transverse_volume            [0, 2.5]       [0, 2.5]
#
#                                    normal in both
# region
# lh_G_and_S_frontomargin_volume                  1
# lh_G_and_S_occipital_inf_volume                 0
# lh_G_and_S_paracentral_volume                   0
# lh_G_and_S_subcentral_volume                    0
# lh_G_and_S_transv_frontopol_volume              0
# ...                                           ...
# rh_S_suborbital_volume                          0
# rh_S_subparietal_volume                         0
# rh_S_temporal_inf_volume                        0
# rh_S_temporal_sup_volume                        0
# rh_S_temporal_transverse_volume                 0
#
# [148 rows x 3 columns]

# %%
class_1 = 0
class_2 = 0
statistical_results = []
ocurrences = []
for dataset, anderson_result in zip(Datasets, results_anderson):
    name = dataset['name']
    data = dataset['data']
    
    # copy all the subjects that belongs to the class 1 and -1 respectively
    # remember that class is a colum  in the end of the raw dataset classified
    class_1 = data[data['class'] == 1].copy()  
    class_2 = data[data['class'] == -1].copy()
    
    # the [:-1] is ommit the last character, in this case ommit the last colum that in this case is the column Class
    # you can print this and see the last part of each print to compare. 
    #print(df.columns.values)
    #print('\n')
    #print(df_stat.columns.values)
    
    df_stat = pd.DataFrame(columns=data.columns.values[:-1])
    
    df_stat.at['t(Xi)', :] = 0
    df_stat.at['MW STAT', :] = 0
    df_stat.at['p-value', :] = 0
    df_stat.at['Dfferent distribution', :] = 0
    #describing distribution
    df_stat.at['mean_strong', :] = 0
    df_stat.at['median_strong', :] = 0
    df_stat.at['SD_strong', :] = 0
    
    df_stat.at['mean_weak', :] = 0
    df_stat.at['median_weak', :] = 0
    df_stat.at['SD_weak', :] = 0
    
    normal = 0
    no_normal = 0
    mix = 0

    #df_stat.head()

    for column in data.columns.values[:-1]:
        normal_weak = anderson_result.at[column, 'normal in weak']
        normal_strong = anderson_result.at[column, 'normal in strong']
        
        df_stat.at['mean_strong', column] = class_1[column].mean()
        df_stat.at['median_strong', column] = class_1[column].median()
        df_stat.at['SD_strong', column] = np.std(class_1[column])
        
        df_stat.at['mean_weak', column] = class_2[column].mean()
        df_stat.at['median_weak', column] = class_2[column].median()
        df_stat.at['SD_weak', column] = np.std(class_2[column])
        

        if  isinstance(normal_weak, list) :
            normal_weak = normal_weak[0]
            
        if  isinstance(normal_strong, list):
            normal_strong = normal_strong[0]
            
        if normal_weak and normal_strong:
            df_stat.at['t(Xi)', column], df_stat.at['p-value', column] = ttest_ind(class_1[column], class_2[column], equal_var=True)
            normal = normal + 1
        elif not normal_weak and not normal_strong:
            df_stat.at['MW STAT', column], df_stat.at['p-value', column] = stats.mannwhitneyu(class_1[column], class_2[column])
            no_normal = no_normal + 1
        else:
            df_stat.at['Dfferent distribution', column] = 1
            df_stat.at['MW STAT', column], df_stat.at['p-value', column] = stats.mannwhitneyu(class_1[column], class_2[column])            
            mix = mix + 1
    
    # T = Transpose index and columns 
    df_stat = df_stat.T.sort_values(by=['p-value'], ascending = True)
    ocurrence = [normal, no_normal, mix] 
    ocurrences.append({'name': name, 'data': ocurrence})
    # returns the las n rows, by defect n = 5 
    #df_stat.tail()
    statistical_results.append(df_stat)
    #saving the results 
    df_stat.to_csv(PATH_OUTPUT + "Estatistical-test_" + name + ".csv")

# %%
print("name ------> normal - no normal - mixture")
print()
for ocurrence in ocurrences:
    name = ocurrence['name']
    data = ocurrence['data']
    
    print(name + " ----> " + str(data))
# Out:
# name ------> normal - no normal - mixture
#
# area ----> [17, 84, 47]
# meancurv ----> [9, 113, 26]
# thickness ----> [42, 60, 46]
# volume ----> [10, 98, 40]

# %% [markdown]
# <h3> Understanding the result</h3>
# <p>
#    with this table we could apreciate the t-test results for the regions in wich, the region has a normal distribution in the 2 labels, and if the region has not a normal distributon we could see the Mean Whitney U test, is the non parametric version of the T-test, also we coul see a flag that tell us if the region has a different distribution between the two labels.
# </p>
# <p>
#     For mean withney U tes
#     306900 the critical value of u less than this value is sifnificant.<br>
#     0 = mean equal distribution<br>
#     close to the critical value  is totally different<br>
#
# </p>

# %%
pd.set_option('display.max_columns',144, 'display.max_rows',144)

# %%
statistical_results[0].head(144)
# Out:
#                                        t(Xi)   MW STAT       p-value  \
# lh_S_circular_insula_sup_area      13.563618       0.0  7.019255e-39
# rh_S_temporal_sup_area              0.000000   86192.5  7.318770e-37
# lh_G_front_sup_area                 0.000000   86911.0  4.027674e-36
# lh_S_temporal_sup_area              0.000000   87196.0  7.881951e-36
# rh_G_and_S_cingul-Ant_area          0.000000   88830.5  3.507518e-34
# rh_G_front_sup_area                 0.000000   89619.5  2.119633e-33
# lh_G_temporal_middle_area           0.000000   89893.5  3.937948e-33
# lh_G_insular_short_area             0.000000   90230.0  8.386557e-33
# rh_S_circular_insula_sup_area       0.000000   90330.0  1.050207e-32
# lh_G_pariet_inf-Angular_area        0.000000   91008.5  4.769005e-32
# rh_G_pariet_inf-Angular_area        0.000000   91693.0  2.157974e-31
# lh_G_front_middle_area              0.000000   91899.0  3.388306e-31
# rh_G_orbital_area                  11.872249       0.0  1.102409e-30
# rh_G_precentral_area                0.000000   92669.0  1.804821e-30
# lh_G_temp_sup-Lateral_area          0.000000   92997.5  3.660833e-30
# rh_G_front_middle_area              0.000000   93058.5  4.174655e-30
# rh_G_temporal_middle_area           0.000000   93515.0  1.107528e-29
# lh_G_pariet_inf-Supramar_area       0.000000   93800.0  2.029317e-29
# lh_G_and_S_cingul-Ant_area          0.000000   94110.0  3.907932e-29
# lh_G_cuneus_area                    0.000000   94244.5  5.187613e-29
# rh_Pole_occipital_area              0.000000   94303.0  5.867307e-29
# rh_G_insular_short_area             0.000000   94439.5  7.805077e-29
# rh_S_oc-temp_lat_area               0.000000   94876.0  1.945057e-28
# lh_G_orbital_area                  11.327679       0.0  3.206049e-28
# rh_G_cuneus_area                    0.000000   95517.5  7.343396e-28
# rh_G_occipital_middle_area          0.000000   95522.5  7.419800e-28
# lh_G_cingul-Post-dorsal_area        0.000000   97012.0  1.532152e-26
# rh_S_pericallosal_area              0.000000   97377.0  3.183086e-26
# lh_G_precentral_area                0.000000   97379.0  3.195967e-26
# lh_Pole_occipital_area              0.000000   98596.5  3.530780e-25
# lh_G_and_S_frontomargin_area       10.557641       0.0  6.834504e-25
# rh_S_front_middle_area              0.000000   99350.0  1.521940e-24
# rh_G_temporal_inf_area             10.406506       0.0  2.925057e-24
# rh_G_postcentral_area               0.000000   99735.0  3.185408e-24
# lh_G_and_S_subcentral_area          0.000000   99751.0  3.284063e-24
# rh_G_pariet_inf-Supramar_area       0.000000   99787.5  3.522128e-24
# rh_G_and_S_cingul-Mid-Post_area     0.000000  100031.5  5.606415e-24
# rh_S_oc-temp_med_and_Lingual_area   0.000000  100451.5  1.242542e-23
# lh_G_temporal_inf_area              0.000000  100547.5  1.489191e-23
# lh_Pole_temporal_area               0.000000  100634.0  1.751948e-23
# rh_G_oc-temp_med-Parahip_area       0.000000  101048.0  3.805508e-23
# lh_S_parieto_occipital_area        10.100907       0.0  5.253287e-23
# lh_G_rectus_area                    0.000000  101341.5  6.565332e-23
# lh_G_occipital_middle_area          0.000000  101468.5  8.316681e-23
# rh_G_occipital_sup_area             0.000000  101849.5  1.679521e-22
# rh_S_circular_insula_inf_area       0.000000  102055.5  2.449939e-22
# lh_S_pericallosal_area              0.000000  102207.5  3.235977e-22
# rh_G_oc-temp_lat-fusifor_area       0.000000  102235.5  3.406221e-22
# lh_S_central_area                   0.000000  102413.5  4.710766e-22
# rh_S_orbital_med-olfact_area        0.000000  102591.0  6.498217e-22
# rh_S_central_area                   0.000000  102720.5  8.219477e-22
# rh_G_temp_sup-Lateral_area          0.000000  102947.5  1.237741e-21
# lh_G_temp_sup-Plan_polar_area       0.000000  102955.5  1.255125e-21
# lh_S_intrapariet_and_P_trans_area   0.000000  103024.5  1.421878e-21
# lh_S_orbital-H_Shaped_area          9.629100       0.0  3.953096e-21
# lh_G_postcentral_area               0.000000  103703.0  4.774551e-21
# rh_G_temp_sup-Plan_tempo_area       0.000000  103797.5  5.642733e-21
# lh_G_oc-temp_med-Parahip_area       0.000000  103850.0  6.192969e-21
# lh_S_circular_insula_ant_area       0.000000  104281.0  1.321429e-20
# rh_G_and_S_subcentral_area          0.000000  104419.0  1.684627e-20
# lh_G_oc-temp_lat-fusifor_area       0.000000  104747.0  2.984518e-20
# lh_G_and_S_cingul-Mid-Post_area     0.000000  104807.0  3.311025e-20
# rh_S_parieto_occipital_area         9.358326       0.0  4.369280e-20
# rh_G_cingul-Post-dorsal_area        0.000000  104988.5  4.532095e-20
# rh_S_temporal_inf_area              0.000000  104992.5  4.566707e-20
# lh_G_cingul-Post-ventral_area       0.000000  105191.5  6.430979e-20
# lh_S_front_sup_area                 0.000000  105293.0  7.666015e-20
# lh_S_circular_insula_inf_area       9.293369       0.0  7.710011e-20
# rh_S_orbital-H_Shaped_area          0.000000  105451.0  1.005038e-19
# lh_S_postcentral_area               0.000000  105765.5  1.719681e-19
# rh_G_and_S_cingul-Mid-Ant_area      0.000000  105847.0  1.974894e-19
# lh_G_and_S_cingul-Mid-Ant_area      0.000000  105938.5  2.306704e-19
# lh_S_orbital_med-olfact_area        9.135797       0.0  3.015833e-19
# rh_G_oc-temp_med-Lingual_area       0.000000  106125.5  3.166074e-19
# lh_S_calcarine_area                 0.000000  106306.0  4.292458e-19
# rh_G_precuneus_area                 0.000000  106423.5  5.229393e-19
# rh_G_Ins_lg_and_S_cent_ins_area     0.000000  106608.0  7.116095e-19
# lh_G_temp_sup-Plan_tempo_area       0.000000  106811.0  9.993945e-19
# rh_G_and_S_frontomargin_area        0.000000  107014.0  1.400099e-18
# rh_G_rectus_area                    0.000000  107017.5  1.407354e-18
# lh_G_oc-temp_med-Lingual_area       0.000000  107283.0  2.185393e-18
# lh_G_front_inf-Opercular_area       0.000000  107714.0  4.432674e-18
# rh_S_front_sup_area                 0.000000  107729.0  4.543500e-18
# rh_S_calcarine_area                 0.000000  107748.0  4.686790e-18
# lh_S_oc_middle_and_Lunatus_area     8.796612       0.0  5.316070e-18
# rh_S_front_inf_area                 0.000000  108116.5  8.533112e-18
# lh_S_front_inf_area                 0.000000  108151.5  9.030893e-18
# lh_G_parietal_sup_area              0.000000  108217.5  1.004861e-17
# lh_S_oc-temp_med_and_Lingual_area   0.000000  108707.0  2.207397e-17
# rh_S_cingul-Marginalis_area         0.000000  109037.5  3.736959e-17
# lh_G_and_S_occipital_inf_area       0.000000  109134.0  4.355697e-17
# lh_S_oc-temp_lat_area               0.000000  109201.0  4.842720e-17
# lh_Lat_Fis-post_area                0.000000  109321.5  5.857574e-17
# rh_Pole_temporal_area               0.000000  109448.5  7.156163e-17
# lh_G_precuneus_area                 0.000000  109517.5  7.977620e-17
# lh_G_Ins_lg_and_S_cent_ins_area     0.000000  109518.5  7.980169e-17
# rh_S_postcentral_area               0.000000  109967.5  1.612053e-16
# rh_S_intrapariet_and_P_trans_area   0.000000  110989.5  7.760422e-16
# lh_S_front_middle_area              0.000000  111080.5  8.909461e-16
# rh_G_and_S_paracentral_area         0.000000  111216.5  1.094492e-15
# lh_G_front_inf-Triangul_area        0.000000  111741.5  2.409512e-15
# lh_Lat_Fis-ant-Horizont_area        0.000000  111955.5  3.308133e-15
# lh_S_subparietal_area               0.000000  111972.5  3.399207e-15
# lh_S_orbital_lateral_area           0.000000  112405.5  6.442780e-15
# lh_S_cingul-Marginalis_area         0.000000  112607.0  8.663202e-15
# rh_S_oc_middle_and_Lunatus_area     7.839154       0.0  1.061347e-14
# rh_G_and_S_transv_frontopol_area    0.000000  112834.0  1.206919e-14
# rh_G_front_inf-Opercular_area       0.000000  113727.0  4.367949e-14
# lh_G_and_S_transv_frontopol_area    0.000000  114051.0  6.916260e-14
# lh_G_occipital_sup_area             0.000000  114187.5  8.387728e-14
# lh_S_temporal_inf_area              0.000000  114260.0  9.290221e-14
# rh_S_oc_sup_and_transversal_area    7.545994       0.0  9.347524e-14
# rh_S_precentral-inf-part_area       0.000000  114834.0  2.070731e-13
# rh_Lat_Fis-post_area                0.000000  114995.5  2.588486e-13
# lh_G_and_S_paracentral_area         0.000000  116378.5  1.690963e-12
# rh_G_temp_sup-Plan_polar_area       0.000000  116404.5  1.750342e-12
# rh_S_precentral-sup-part_area       0.000000  116480.0  1.935837e-12
# rh_S_interm_prim-Jensen_area        0.000000  117003.5  3.864031e-12
# rh_S_circular_insula_ant_area       0.000000  117331.0  5.923651e-12
# rh_G_temp_sup-G_T_transv_area       0.000000  117376.5  6.280712e-12
# rh_G_front_inf-Triangul_area        0.000000  117667.0  9.154458e-12
# rh_G_cingul-Post-ventral_area       0.000000  118150.0  1.696328e-11
# lh_S_precentral-sup-part_area       0.000000  118442.5  2.460775e-11
# lh_S_precentral-inf-part_area       0.000000  118615.5  3.059451e-11
# rh_G_and_S_occipital_inf_area       0.000000  118792.5  3.818797e-11
# rh_S_subparietal_area               0.000000  118891.5  4.320932e-11
# lh_S_collat_transv_ant_area         0.000000  119049.5  5.258976e-11
# rh_S_collat_transv_ant_area         0.000000  119241.0  6.665069e-11
# rh_G_parietal_sup_area              0.000000  120006.0  1.696105e-10
# rh_G_subcallosal_area               0.000000  120616.5  3.521592e-10
# lh_S_temporal_transverse_area       6.232991       0.0  6.496811e-10
# rh_Lat_Fis-ant-Horizont_area        0.000000  121444.0  9.287956e-10
# rh_G_front_inf-Orbital_area         0.000000  121785.0  1.375651e-09
# lh_S_collat_transv_post_area        0.000000  121946.5  1.655265e-09
# lh_G_temp_sup-G_T_transv_area       0.000000  122137.5  2.057149e-09
# lh_S_suborbital_area                0.000000  123734.0  1.204297e-08
# lh_G_front_inf-Orbital_area         0.000000  123759.5  1.237229e-08
# lh_S_occipital_ant_area             0.000000  123998.0  1.599946e-08
# rh_S_suborbital_area                0.000000  124117.0  1.816277e-08
# rh_S_orbital_lateral_area           0.000000  124140.5  1.862426e-08
# lh_G_subcallosal_area               0.000000  126286.5  1.694531e-07
# lh_Lat_Fis-ant-Vertical_area        0.000000  126542.0  2.179971e-07
# rh_S_occipital_ant_area             0.000000  126546.5  2.190575e-07
# rh_S_collat_transv_post_area        5.205922       0.0  2.300209e-07
#
#                                    Dfferent distribution  mean_strong  \
# lh_S_circular_insula_sup_area                        0.0  1270.649091
# rh_S_temporal_sup_area                               1.0  4486.590909
# lh_G_front_sup_area                                  1.0  5147.585455
# lh_S_temporal_sup_area                               1.0  4059.396364
# rh_G_and_S_cingul-Ant_area                           0.0  2067.025455
# rh_G_front_sup_area                                  1.0  4895.070909
# lh_G_temporal_middle_area                            1.0  2079.336364
# lh_G_insular_short_area                              1.0   480.903636
# rh_S_circular_insula_sup_area                        1.0   998.721818
# lh_G_pariet_inf-Angular_area                         0.0  1779.423636
# rh_G_pariet_inf-Angular_area                         1.0  2173.423636
# lh_G_front_middle_area                               1.0  3356.167273
# rh_G_orbital_area                                    0.0  1875.087273
# rh_G_precentral_area                                 0.0  1784.054545
# lh_G_temp_sup-Lateral_area                           0.0  1460.836364
# rh_G_front_middle_area                               1.0  3031.372727
# rh_G_temporal_middle_area                            1.0  2178.478182
# lh_G_pariet_inf-Supramar_area                        0.0  2158.914545
# lh_G_and_S_cingul-Ant_area                           1.0  1751.650909
# lh_G_cuneus_area                                     1.0  1385.229091
# rh_Pole_occipital_area                               1.0  2075.169091
# rh_G_insular_short_area                              1.0   437.800000
# rh_S_oc-temp_lat_area                                1.0   762.390909
# lh_G_orbital_area                                    0.0  1777.710909
# rh_G_cuneus_area                                     1.0  1453.967273
# rh_G_occipital_middle_area                           0.0  1635.700000
# lh_G_cingul-Post-dorsal_area                         0.0   442.589091
# rh_S_pericallosal_area                               0.0  1194.714545
# lh_G_precentral_area                                 0.0  1771.814545
# lh_Pole_occipital_area                               0.0  1311.878182
# lh_G_and_S_frontomargin_area                         0.0   887.823636
# rh_S_front_middle_area                               1.0  1705.396364
# rh_G_temporal_inf_area                               0.0  1853.270909
# rh_G_postcentral_area                                0.0  1387.634545
# lh_G_and_S_subcentral_area                           0.0  1057.049091
# rh_G_pariet_inf-Supramar_area                        0.0  1947.256364
# rh_G_and_S_cingul-Mid-Post_area                      0.0  1092.287273
# rh_S_oc-temp_med_and_Lingual_area                    1.0  1484.140000
# lh_G_temporal_inf_area                               1.0  1980.163636
# lh_Pole_temporal_area                                0.0  1317.392727
# rh_G_oc-temp_med-Parahip_area                        0.0  1118.109091
# lh_S_parieto_occipital_area                          0.0  1513.847273
# lh_G_rectus_area                                     1.0   685.963636
# lh_G_occipital_middle_area                           0.0  1517.416364
# rh_G_occipital_sup_area                              1.0  1212.361818
# rh_S_circular_insula_inf_area                        1.0   912.074545
# lh_S_pericallosal_area                               0.0   910.016364
# rh_G_oc-temp_lat-fusifor_area                        0.0  1379.274545
# lh_S_central_area                                    0.0  2330.978182
# rh_S_orbital_med-olfact_area                         1.0   616.829091
# rh_S_central_area                                    0.0  2257.101818
# rh_G_temp_sup-Lateral_area                           0.0  1282.369091
# lh_G_temp_sup-Plan_polar_area                        1.0   480.954545
# lh_S_intrapariet_and_P_trans_area                    1.0  2306.829091
# lh_S_orbital-H_Shaped_area                           0.0  1017.692727
# lh_G_postcentral_area                                0.0  1514.380000
# rh_G_temp_sup-Plan_tempo_area                        1.0   596.078182
# lh_G_oc-temp_med-Parahip_area                        0.0   931.976364
# lh_S_circular_insula_ant_area                        0.0   376.027273
# rh_G_and_S_subcentral_area                           0.0   958.896364
# lh_G_oc-temp_lat-fusifor_area                        0.0  1407.612727
# lh_G_and_S_cingul-Mid-Post_area                      0.0   982.640000
# rh_S_parieto_occipital_area                          0.0  1623.030909
# rh_G_cingul-Post-dorsal_area                         0.0   411.052727
# rh_S_temporal_inf_area                               1.0  1003.385455
# lh_G_cingul-Post-ventral_area                        0.0   277.103636
# lh_S_front_sup_area                                  1.0  2134.687273
# lh_S_circular_insula_inf_area                        0.0  1019.754545
# rh_S_orbital-H_Shaped_area                           1.0  1058.336364
# lh_S_postcentral_area                                0.0  2123.947273
# rh_G_and_S_cingul-Mid-Ant_area                       1.0  1130.087273
# lh_G_and_S_cingul-Mid-Ant_area                       0.0  1023.767273
# lh_S_orbital_med-olfact_area                         0.0   642.750909
# rh_G_oc-temp_med-Lingual_area                        1.0  2024.360000
# lh_S_calcarine_area                                  1.0  2057.843636
# rh_G_precuneus_area                                  0.0  1911.636364
# rh_G_Ins_lg_and_S_cent_ins_area                      0.0   371.170909
# lh_G_temp_sup-Plan_tempo_area                        0.0   727.992727
# rh_G_and_S_frontomargin_area                         1.0   740.158182
# rh_G_rectus_area                                     0.0   505.707273
# lh_G_oc-temp_med-Lingual_area                        1.0  2092.347273
# lh_G_front_inf-Opercular_area                        0.0  1033.790909
# rh_S_front_sup_area                                  1.0  1980.170909
# rh_S_calcarine_area                                  1.0  1957.194545
# lh_S_oc_middle_and_Lunatus_area                      0.0   879.710909
# rh_S_front_inf_area                                  0.0  1615.216364
# lh_S_front_inf_area                                  0.0  1773.727273
# lh_G_parietal_sup_area                               0.0  2101.265455
# lh_S_oc-temp_med_and_Lingual_area                    0.0  1585.254545
# rh_S_cingul-Marginalis_area                          0.0   950.329091
# lh_G_and_S_occipital_inf_area                        1.0  1169.900000
# lh_S_oc-temp_lat_area                                1.0   711.001818
# lh_Lat_Fis-post_area                                 0.0   843.772727
# rh_Pole_temporal_area                                0.0  1256.807273
# lh_G_precuneus_area                                  0.0  1890.241818
# lh_G_Ins_lg_and_S_cent_ins_area                      1.0   341.932727
# rh_S_postcentral_area                                0.0  1808.394545
# rh_S_intrapariet_and_P_trans_area                    0.0  2369.934545
# lh_S_front_middle_area                               0.0  1209.020000
# rh_G_and_S_paracentral_area                          0.0   832.621818
# lh_G_front_inf-Triangul_area                         0.0   812.983636
# lh_Lat_Fis-ant-Horizont_area                         0.0   241.710909
# lh_S_subparietal_area                                0.0   788.067273
# lh_S_orbital_lateral_area                            1.0   310.163636
# lh_S_cingul-Marginalis_area                          0.0   789.970909
# rh_S_oc_middle_and_Lunatus_area                      0.0   795.116364
# rh_G_and_S_transv_frontopol_area                     0.0   840.090909
# rh_G_front_inf-Opercular_area                        0.0   931.432727
# lh_G_and_S_transv_frontopol_area                     1.0   515.521818
# lh_G_occipital_sup_area                              0.0  1061.694545
# lh_S_temporal_inf_area                               1.0  1049.332727
# rh_S_oc_sup_and_transversal_area                     0.0  1158.376364
# rh_S_precentral-inf-part_area                        0.0  1202.989091
# rh_Lat_Fis-post_area                                 0.0  1000.105455
# lh_G_and_S_paracentral_area                          0.0   920.852727
# rh_G_temp_sup-Plan_polar_area                        0.0   513.040000
# rh_S_precentral-sup-part_area                        0.0  1043.567273
# rh_S_interm_prim-Jensen_area                         0.0   400.549091
# rh_S_circular_insula_ant_area                        0.0   428.696364
# rh_G_temp_sup-G_T_transv_area                        0.0   274.883636
# rh_G_front_inf-Triangul_area                         0.0   785.514545
# rh_G_cingul-Post-ventral_area                        0.0   206.492727
# lh_S_precentral-sup-part_area                        0.0   987.883636
# lh_S_precentral-inf-part_area                        0.0  1089.285455
# rh_G_and_S_occipital_inf_area                        0.0   953.490909
# rh_S_subparietal_area                                0.0   893.423636
# lh_S_collat_transv_ant_area                          0.0   753.507273
# rh_S_collat_transv_ant_area                          0.0   769.130909
# rh_G_parietal_sup_area                               0.0  1711.214545
# rh_G_subcallosal_area                                0.0   229.180000
# lh_S_temporal_transverse_area                        0.0   273.932727
# rh_Lat_Fis-ant-Horizont_area                         1.0   292.678182
# rh_G_front_inf-Orbital_area                          0.0   249.103636
# lh_S_collat_transv_post_area                         1.0   313.187273
# lh_G_temp_sup-G_T_transv_area                        0.0   358.529091
# lh_S_suborbital_area                                 0.0   490.869091
# lh_G_front_inf-Orbital_area                          0.0   210.983636
# lh_S_occipital_ant_area                              0.0   602.809091
# rh_S_suborbital_area                                 1.0   246.267273
# rh_S_orbital_lateral_area                            1.0   350.476364
# lh_G_subcallosal_area                                0.0   396.605455
# lh_Lat_Fis-ant-Vertical_area                         0.0   209.452727
# rh_S_occipital_ant_area                              0.0   577.309091
# rh_S_collat_transv_post_area                         0.0   409.729091
#
#                                    median_strong   SD_strong    mean_weak  \
# lh_S_circular_insula_sup_area             1267.0  140.901573  1163.489247
# rh_S_temporal_sup_area                    4468.0  577.041818  4058.951613
# lh_G_front_sup_area                       5141.5  634.875744  4675.109319
# lh_S_temporal_sup_area                    4065.5  536.005433  3664.353047
# rh_G_and_S_cingul-Ant_area                2083.5  270.456912  1870.354839
# rh_G_front_sup_area                       4888.0  581.927290  4475.756272
# lh_G_temporal_middle_area                 2079.5  306.723716  1861.550179
# lh_G_insular_short_area                    476.0   78.187210   425.077061
# rh_S_circular_insula_sup_area              999.0  125.609919   911.643369
# lh_G_pariet_inf-Angular_area              1759.0  298.406289  1572.311828
# rh_G_pariet_inf-Angular_area              2168.5  348.929986  1935.589606
# lh_G_front_middle_area                    3332.5  535.530161  2994.129032
# rh_G_orbital_area                         1870.5  220.026865  1727.387097
# rh_G_precentral_area                      1767.0  253.876621  1618.827957
# lh_G_temp_sup-Lateral_area                1448.0  191.469890  1336.188172
# rh_G_front_middle_area                    3027.5  490.684480  2711.356631
# rh_G_temporal_middle_area                 2185.5  299.391156  1981.378136
# lh_G_pariet_inf-Supramar_area             2128.0  351.823925  1926.887097
# lh_G_and_S_cingul-Ant_area                1747.5  258.652856  1580.652330
# lh_G_cuneus_area                          1382.0  219.673225  1236.575269
# rh_Pole_occipital_area                    2075.0  296.788622  1878.349462
# rh_G_insular_short_area                    432.0   78.320507   385.137993
# rh_S_oc-temp_lat_area                      758.0  163.822603   653.797491
# lh_G_orbital_area                         1777.0  203.067069  1644.062724
# rh_G_cuneus_area                          1452.5  230.421927  1308.539427
# rh_G_occipital_middle_area                1623.0  279.349372  1460.449821
# lh_G_cingul-Post-dorsal_area               429.0   95.676416   384.711470
# rh_S_pericallosal_area                    1148.5  358.339418  1041.955197
# lh_G_precentral_area                      1756.0  266.462404  1620.143369
# lh_Pole_occipital_area                    1297.0  191.827332  1200.754480
# lh_G_and_S_frontomargin_area               885.5  130.347535   810.008961
# rh_S_front_middle_area                    1707.5  306.975977  1525.191756
# rh_G_temporal_inf_area                    1842.5  315.742774  1672.220430
# rh_G_postcentral_area                     1373.5  205.963940  1269.464158
# lh_G_and_S_subcentral_area                1050.5  168.472073   956.080645
# rh_G_pariet_inf-Supramar_area             1929.0  332.126490  1749.989247
# rh_G_and_S_cingul-Mid-Post_area           1082.0  164.658692   994.044803
# rh_S_oc-temp_med_and_Lingual_area         1480.0  227.350199  1351.550179
# lh_G_temporal_inf_area                    1992.0  337.100118  1783.059140
# lh_Pole_temporal_area                     1298.0  156.641915  1221.734767
# rh_G_oc-temp_med-Parahip_area             1109.5  188.062008  1007.270609
# lh_S_parieto_occipital_area               1504.0  249.784493  1367.129032
# lh_G_rectus_area                           683.0   80.506050   641.448029
# lh_G_occipital_middle_area                1510.0  256.129149  1370.284946
# rh_G_occipital_sup_area                   1200.5  189.102594  1105.706093
# rh_S_circular_insula_inf_area              912.5  109.969499   848.799283
# lh_S_pericallosal_area                     839.5  324.815279   787.250896
# rh_G_oc-temp_lat-fusifor_area             1363.5  263.601619  1224.611111
# lh_S_central_area                         2316.5  257.064045  2191.602151
# rh_S_orbital_med-olfact_area               612.0  103.358968   556.340502
# rh_S_central_area                         2250.5  235.830826  2125.942652
# rh_G_temp_sup-Lateral_area                1266.5  181.971127  1178.401434
# lh_G_temp_sup-Plan_polar_area              477.5  100.073208   424.761649
# lh_S_intrapariet_and_P_trans_area         2300.5  330.921715  2124.494624
# lh_S_orbital-H_Shaped_area                1021.0  133.541380   942.847670
# lh_G_postcentral_area                     1496.5  237.476941  1383.974910
# rh_G_temp_sup-Plan_tempo_area              593.0  110.110058   535.001792
# lh_G_oc-temp_med-Parahip_area              909.5  171.532253   845.507168
# lh_S_circular_insula_ant_area              370.0   67.126970   339.478495
# rh_G_and_S_subcentral_area                 949.0  161.045827   870.442652
# lh_G_oc-temp_lat-fusifor_area             1366.5  272.431297  1260.172043
# lh_G_and_S_cingul-Mid-Post_area            965.5  135.481785   909.707885
# rh_S_parieto_occipital_area               1631.0  271.548732  1474.711470
# rh_G_cingul-Post-dorsal_area               400.0   87.088351   363.973118
# rh_S_temporal_inf_area                    1012.5  224.136534   883.362007
# lh_G_cingul-Post-ventral_area              247.0  120.914493   232.974910
# lh_S_front_sup_area                       2116.0  316.403098  1972.100358
# lh_S_circular_insula_inf_area             1015.0  103.630900   964.267025
# rh_S_orbital-H_Shaped_area                1055.0  147.021685   976.181004
# lh_S_postcentral_area                     2108.5  322.680753  1948.890681
# rh_G_and_S_cingul-Mid-Ant_area            1124.0  167.190397  1041.141577
# lh_G_and_S_cingul-Mid-Ant_area            1008.5  175.725117   935.949821
# lh_S_orbital_med-olfact_area               647.5  109.533331   586.623656
# rh_G_oc-temp_med-Lingual_area             2019.0  307.633680  1863.759857
# lh_S_calcarine_area                       2051.5  350.026400  1866.417563
# rh_G_precuneus_area                       1885.0  307.148502  1755.564516
# rh_G_Ins_lg_and_S_cent_ins_area            366.0   66.877200   335.331541
# lh_G_temp_sup-Plan_tempo_area              717.0  153.718337   649.324373
# rh_G_and_S_frontomargin_area               737.0  107.266747   683.654122
# rh_G_rectus_area                           503.5   66.165905   470.797491
# lh_G_oc-temp_med-Lingual_area             2097.5  321.503430  1927.161290
# lh_G_front_inf-Opercular_area             1020.5  176.715380   946.293907
# rh_S_front_sup_area                       1970.0  302.375101  1833.252688
# rh_S_calcarine_area                       1948.0  337.172867  1786.145161
# lh_S_oc_middle_and_Lunatus_area            890.0  192.698148   780.227599
# rh_S_front_inf_area                       1594.5  270.259220  1485.163082
# lh_S_front_inf_area                       1749.5  299.400872  1624.612903
# lh_G_parietal_sup_area                    2076.0  334.021570  1929.118280
# lh_S_oc-temp_med_and_Lingual_area         1569.0  259.666375  1454.881720
# rh_S_cingul-Marginalis_area                937.0  148.278837   876.754480
# lh_G_and_S_occipital_inf_area             1169.0  202.610856  1069.648746
# lh_S_oc-temp_lat_area                      715.5  171.605367   626.767025
# lh_Lat_Fis-post_area                       826.5  132.411896   778.055556
# rh_Pole_temporal_area                     1253.5  149.281501  1184.172043
# lh_G_precuneus_area                       1851.0  297.111980  1740.544803
# lh_G_Ins_lg_and_S_cent_ins_area            340.0   62.029385   311.381720
# rh_S_postcentral_area                     1795.5  323.840301  1654.050179
# rh_S_intrapariet_and_P_trans_area         2349.0  335.846474  2204.349462
# lh_S_front_middle_area                    1198.0  244.038301  1099.186380
# rh_G_and_S_paracentral_area                825.0  130.370809   773.258065
# lh_G_front_inf-Triangul_area               808.5  160.152092   740.905018
# lh_Lat_Fis-ant-Horizont_area               238.0   44.744020   221.810036
# lh_S_subparietal_area                      778.0  168.142237   709.664875
# lh_S_orbital_lateral_area                  310.0   66.519461   278.014337
# lh_S_cingul-Marginalis_area                777.0  116.818192   736.722222
# rh_S_oc_middle_and_Lunatus_area            794.5  209.431354   701.777778
# rh_G_and_S_transv_frontopol_area           826.0  163.304977   765.575269
# rh_G_front_inf-Opercular_area              908.0  174.069960   855.089606
# lh_G_and_S_transv_frontopol_area           512.0  100.425597   474.363799
# lh_G_occipital_sup_area                   1052.0  165.125862   993.146953
# lh_S_temporal_inf_area                    1043.5  243.159335   938.374552
# rh_S_oc_sup_and_transversal_area          1165.0  217.382617  1062.838710
# rh_S_precentral-inf-part_area             1187.0  215.934704  1115.068100
# rh_Lat_Fis-post_area                       984.0  108.055187   953.008961
# lh_G_and_S_paracentral_area                910.0  141.809303   863.983871
# rh_G_temp_sup-Plan_polar_area              505.5   99.377784   471.629032
# rh_S_precentral-sup-part_area             1034.0  221.085788   953.637993
# rh_S_interm_prim-Jensen_area               379.0  175.267267   326.512545
# rh_S_circular_insula_ant_area              421.0   80.991181   396.532258
# rh_G_temp_sup-G_T_transv_area              268.0   54.905614   252.897849
# rh_G_front_inf-Triangul_area               770.0  171.099426   716.415771
# rh_G_cingul-Post-ventral_area              201.0   44.388153   188.854839
# lh_S_precentral-sup-part_area              973.0  198.667829   909.252688
# lh_S_precentral-inf-part_area             1072.5  200.162989  1013.069892
# rh_G_and_S_occipital_inf_area              929.0  189.341805   879.587814
# rh_S_subparietal_area                      877.0  220.468280   814.354839
# lh_S_collat_transv_ant_area                742.0  183.468687   680.243728
# rh_S_collat_transv_ant_area                763.0  182.732087   696.623656
# rh_G_parietal_sup_area                    1694.0  277.726722  1609.073477
# rh_G_subcallosal_area                      215.0  100.888752   191.655914
# lh_S_temporal_transverse_area              271.5   54.189004   254.931900
# rh_Lat_Fis-ant-Horizont_area               291.0   58.792919   272.213262
# rh_G_front_inf-Orbital_area                242.0   53.950197   230.229391
# lh_S_collat_transv_post_area               312.5   71.316143   289.456989
# lh_G_temp_sup-G_T_transv_area              350.5   75.075490   332.974910
# lh_S_suborbital_area                       485.5   83.908485   462.508961
# lh_G_front_inf-Orbital_area                210.0   49.190702   195.218638
# lh_S_occipital_ant_area                    594.0  166.424337   549.023297
# rh_S_suborbital_area                       247.5   72.204479   222.587814
# rh_S_orbital_lateral_area                  350.0   79.030848   324.281362
# lh_G_subcallosal_area                      399.5  179.540582   341.786738
# lh_Lat_Fis-ant-Vertical_area               205.5   59.383197   191.127240
# rh_S_occipital_ant_area                    568.0  156.602122   530.080645
# rh_S_collat_transv_post_area               406.0  105.035515   378.362007
#
#                                    median_weak     SD_weak
# lh_S_circular_insula_sup_area           1165.5  121.241764
# rh_S_temporal_sup_area                  4041.5  453.584785
# lh_G_front_sup_area                     4646.0  531.526614
# lh_S_temporal_sup_area                  3652.0  430.791073
# rh_G_and_S_cingul-Ant_area              1865.0  240.161728
# rh_G_front_sup_area                     4447.0  522.377541
# lh_G_temporal_middle_area               1842.0  264.118674
# lh_G_insular_short_area                  414.0   70.110252
# rh_S_circular_insula_sup_area            906.0  107.537507
# lh_G_pariet_inf-Angular_area            1558.5  235.890769
# rh_G_pariet_inf-Angular_area            1901.5  300.828977
# lh_G_front_middle_area                  2969.0  450.190256
# rh_G_orbital_area                       1720.5  193.012732
# rh_G_precentral_area                    1604.0  212.000209
# lh_G_temp_sup-Lateral_area              1323.0  156.329707
# rh_G_front_middle_area                  2671.0  421.614060
# rh_G_temporal_middle_area               1973.0  266.007058
# lh_G_pariet_inf-Supramar_area           1907.0  293.818940
# lh_G_and_S_cingul-Ant_area              1562.0  226.652065
# lh_G_cuneus_area                        1222.0  207.003551
# rh_Pole_occipital_area                  1850.0  267.137994
# rh_G_insular_short_area                  383.0   71.691248
# rh_S_oc-temp_lat_area                    643.0  152.772092
# lh_G_orbital_area                       1648.0  189.149828
# rh_G_cuneus_area                        1314.0  212.111338
# rh_G_occipital_middle_area              1442.0  237.557667
# lh_G_cingul-Post-dorsal_area             377.0   74.754611
# rh_S_pericallosal_area                  1005.0  274.251278
# lh_G_precentral_area                    1604.5  211.889716
# lh_Pole_occipital_area                  1188.0  159.581517
# lh_G_and_S_frontomargin_area             806.0  114.355612
# rh_S_front_middle_area                  1513.5  280.855275
# rh_G_temporal_inf_area                  1657.0  260.598381
# rh_G_postcentral_area                   1247.5  183.310315
# lh_G_and_S_subcentral_area               939.0  149.616148
# rh_G_pariet_inf-Supramar_area           1743.0  262.355978
# rh_G_and_S_cingul-Mid-Post_area          977.0  146.407689
# rh_S_oc-temp_med_and_Lingual_area       1340.0  209.260321
# lh_G_temporal_inf_area                  1762.5  297.593005
# lh_Pole_temporal_area                   1211.0  145.516093
# rh_G_oc-temp_med-Parahip_area            997.0  163.346061
# lh_S_parieto_occipital_area             1358.0  233.095273
# lh_G_rectus_area                         638.5   67.161017
# lh_G_occipital_middle_area              1362.0  232.111191
# rh_G_occipital_sup_area                 1096.0  167.337745
# rh_S_circular_insula_inf_area            842.0   95.629283
# lh_S_pericallosal_area                   739.0  245.039127
# rh_G_oc-temp_lat-fusifor_area           1217.5  235.951861
# lh_S_central_area                       2184.5  221.885718
# rh_S_orbital_med-olfact_area             554.0   91.581400
# rh_S_central_area                       2110.5  231.050857
# rh_G_temp_sup-Lateral_area              1169.5  147.416291
# lh_G_temp_sup-Plan_polar_area            422.0   86.855536
# lh_S_intrapariet_and_P_trans_area       2108.0  294.059352
# lh_S_orbital-H_Shaped_area               943.5  124.865591
# lh_G_postcentral_area                   1370.5  202.683342
# rh_G_temp_sup-Plan_tempo_area            528.0   97.004794
# lh_G_oc-temp_med-Parahip_area            839.0  114.436233
# lh_S_circular_insula_ant_area            333.5   55.733223
# rh_G_and_S_subcentral_area               860.0  138.048195
# lh_G_oc-temp_lat-fusifor_area           1244.0  238.885778
# lh_G_and_S_cingul-Mid-Post_area          902.0  108.986150
# rh_S_parieto_occipital_area             1474.5  255.387507
# rh_G_cingul-Post-dorsal_area             358.5   75.129620
# rh_S_temporal_inf_area                   876.5  200.004878
# lh_G_cingul-Post-ventral_area            204.0  119.742478
# lh_S_front_sup_area                     1950.0  282.994580
# lh_S_circular_insula_inf_area            963.5   94.794640
# rh_S_orbital-H_Shaped_area               976.0  132.902845
# lh_S_postcentral_area                   1937.0  281.823734
# rh_G_and_S_cingul-Mid-Ant_area          1032.0  148.528601
# lh_G_and_S_cingul-Mid-Ant_area           921.0  156.256960
# lh_S_orbital_med-olfact_area             586.0   94.321316
# rh_G_oc-temp_med-Lingual_area           1845.0  278.400957
# lh_S_calcarine_area                     1851.5  325.973391
# rh_G_precuneus_area                     1729.5  275.881127
# rh_G_Ins_lg_and_S_cent_ins_area          329.0   61.885657
# lh_G_temp_sup-Plan_tempo_area            637.0  136.972764
# rh_G_and_S_frontomargin_area             675.5   97.532719
# rh_G_rectus_area                         466.5   59.959546
# lh_G_oc-temp_med-Lingual_area           1910.5  300.925542
# lh_G_front_inf-Opercular_area            926.5  147.380532
# rh_S_front_sup_area                     1811.0  273.363581
# rh_S_calcarine_area                     1746.0  308.144898
# lh_S_oc_middle_and_Lunatus_area          781.5  183.351202
# rh_S_front_inf_area                     1467.0  226.106115
# lh_S_front_inf_area                     1597.5  255.595904
# lh_G_parietal_sup_area                  1904.5  309.170929
# lh_S_oc-temp_med_and_Lingual_area       1422.5  241.886404
# rh_S_cingul-Marginalis_area              868.0  131.977864
# lh_G_and_S_occipital_inf_area           1052.0  188.618972
# lh_S_oc-temp_lat_area                    618.0  144.107249
# lh_Lat_Fis-post_area                     768.5  106.572785
# rh_Pole_temporal_area                   1169.0  141.013494
# lh_G_precuneus_area                     1723.5  274.641077
# lh_G_Ins_lg_and_S_cent_ins_area          309.0   52.850837
# rh_S_postcentral_area                   1641.0  280.584837
# rh_S_intrapariet_and_P_trans_area       2195.5  311.921685
# lh_S_front_middle_area                  1071.0  214.051876
# rh_G_and_S_paracentral_area              769.0  116.069585
# lh_G_front_inf-Triangul_area             729.5  133.811588
# lh_Lat_Fis-ant-Horizont_area             217.0   40.015003
# lh_S_subparietal_area                    696.0  153.963096
# lh_S_orbital_lateral_area                279.0   65.052472
# lh_S_cingul-Marginalis_area              731.0   98.537095
# rh_S_oc_middle_and_Lunatus_area          706.5  186.010899
# rh_G_and_S_transv_frontopol_area         756.5  143.367777
# rh_G_front_inf-Opercular_area            841.5  134.438401
# lh_G_and_S_transv_frontopol_area         469.5   87.297304
# lh_G_occipital_sup_area                  985.5  145.467729
# lh_S_temporal_inf_area                   926.5  227.632134
# rh_S_oc_sup_and_transversal_area        1065.5  203.530459
# rh_S_precentral-inf-part_area           1095.0  194.496646
# rh_Lat_Fis-post_area                     947.0   93.904597
# lh_G_and_S_paracentral_area              851.5  121.519169
# rh_G_temp_sup-Plan_polar_area            464.0   93.186773
# rh_S_precentral-sup-part_area            943.0  184.191476
# rh_S_interm_prim-Jensen_area             310.5  139.067552
# rh_S_circular_insula_ant_area            387.5   73.634364
# rh_G_temp_sup-G_T_transv_area            247.0   48.832373
# rh_G_front_inf-Triangul_area             709.0  151.119001
# rh_G_cingul-Post-ventral_area            186.0   38.930442
# lh_S_precentral-sup-part_area            902.5  166.606921
# lh_S_precentral-inf-part_area            997.5  186.137789
# rh_G_and_S_occipital_inf_area            872.0  165.236071
# rh_S_subparietal_area                    789.0  196.977027
# lh_S_collat_transv_ant_area              673.5  167.213838
# rh_S_collat_transv_ant_area              688.5  157.311297
# rh_G_parietal_sup_area                  1578.5  268.335390
# rh_G_subcallosal_area                    181.0   84.129060
# lh_S_temporal_transverse_area            254.0   46.984353
# rh_Lat_Fis-ant-Horizont_area             269.0   52.243050
# rh_G_front_inf-Orbital_area              224.0   51.252671
# lh_S_collat_transv_post_area             285.5   65.769507
# lh_G_temp_sup-G_T_transv_area            321.0   71.252085
# lh_S_suborbital_area                     457.5   82.870537
# lh_G_front_inf-Orbital_area              192.0   42.553726
# lh_S_occipital_ant_area                  540.5  149.938606
# rh_S_suborbital_area                     222.0   74.972721
# rh_S_orbital_lateral_area                320.0   72.763485
# lh_G_subcallosal_area                    339.0  157.934141
# lh_Lat_Fis-ant-Vertical_area             186.0   57.852859
# rh_S_occipital_ant_area                  514.0  133.430337
# rh_S_collat_transv_post_area             375.5   95.167245
