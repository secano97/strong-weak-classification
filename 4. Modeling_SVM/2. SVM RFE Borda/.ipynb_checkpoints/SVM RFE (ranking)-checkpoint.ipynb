# %% [markdown]
# # <center> <b> <h1>   2. SVM RFE (ranking) </h1></b></center>

# %%
import joblib
from sklearn.svm import SVC
from sklearn.feature_selection import RFECV

import pandas as pd

PATH_PKL = "../1. SVM RFE (All features)/output/"
PATH_DATASETS = "../../2_Data_preparation/2_Split_Raw_Datasets/output/"

# %%
def readCsvs(split):
    datasets = []
    constant1 = 'X_'
    constant2 = '_' + split
    features = ['area', 'meancurv', 'thickness', 'volume']

    for feature in features:
        df = pd.read_csv(PATH_DATASETS + constant1 + feature + constant2 +'.csv', index_col=0)
        datasets.append({'name': feature, 'data': df})
    return datasets

# %%
def readClf():
    clasificators = []
    constant1 = "SVM RFE (AllFeatures) "
    features = ['area', 'meancurv', 'thickness', 'volume']

    for feature in features:
        clf = joblib.load(PATH_PKL + constant1 + feature + '.pkl')
        clasificators.append(clf)
        
    return clasificators

# %% [markdown]
# # 1. Prepare the Data

# %%
df_X_tr = readCsvs('train')
df_X_tr[0]['data'].shape
# Out:
# (550, 148)

# %%
clfs = readClf()
clfs[0]
# Out:
# {'name': 'area',
#  'rfecv': RFECV(cv=StratifiedKFold(n_splits=5, random_state=None, shuffle=False),
#        estimator=SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#                      decision_function_shape='ovr', degree=3,
#                      gamma='auto_deprecated', kernel='linear', max_iter=1000000,
#                      probability=False, random_state=None, shrinking=True,
#                      tol=0.001, verbose=False),
#        min_features_to_select=1, n_jobs=-1, scoring='accuracy', step=1,
#        verbose=True),
#  'kernel': 'linear'}

# %% [markdown]
# # 2. Identify the most important feature of the SVM RFE

# %%
rankings =[]
# print the name
for feature, rfcv in zip(df_X_tr, clfs):
    df_fetures = pd.DataFrame(columns=['Name','Ranking', 'Support'])
    df_fetures.set_index('Name', inplace = True)
    name = feature['name']
    data = feature['data']
    rfcv_data = rfcv['rfecv']
    #df_fetures.head()
    for roi in zip(data.columns.values, rfcv_data.support_, rfcv_data.ranking_):
        print(roi)
        df_fetures.at[roi[0],"Ranking"] = roi[1]
        df_fetures.at[roi[0],"Support"] = roi[2]
    rankings.append({'name' : name, 'data' : df_fetures})
    print("end with: " + name + '\n')
# Out:
# ('lh_G_and_S_frontomargin_area', False, 76)
# ('lh_G_and_S_occipital_inf_area', False, 118)
# ('lh_G_and_S_paracentral_area', False, 10)
# ('lh_G_and_S_subcentral_area', False, 96)
# ('lh_G_and_S_transv_frontopol_area', False, 44)
# ('lh_G_and_S_cingul-Ant_area', False, 140)
# ('lh_G_and_S_cingul-Mid-Ant_area', True, 1)
# ('lh_G_and_S_cingul-Mid-Post_area', False, 105)
# ('lh_G_cingul-Post-dorsal_area', False, 50)
# ('lh_G_cingul-Post-ventral_area', False, 144)
# ('lh_G_cuneus_area', False, 22)
# ('lh_G_front_inf-Opercular_area', False, 115)
# ('lh_G_front_inf-Orbital_area', False, 71)
# ('lh_G_front_inf-Triangul_area', False, 114)
# ('lh_G_front_middle_area', False, 142)
# ('lh_G_front_sup_area', False, 129)
# ('lh_G_Ins_lg_and_S_cent_ins_area', False, 108)
# ('lh_G_insular_short_area', False, 36)
# ('lh_G_occipital_middle_area', False, 12)
# ('lh_G_occipital_sup_area', False, 83)
# ('lh_G_oc-temp_lat-fusifor_area', False, 104)
# ('lh_G_oc-temp_med-Lingual_area', False, 34)
# ('lh_G_oc-temp_med-Parahip_area', True, 1)
# ('lh_G_orbital_area', False, 45)
# ('lh_G_pariet_inf-Angular_area', False, 145)
# ('lh_G_pariet_inf-Supramar_area', False, 91)
# ('lh_G_parietal_sup_area', False, 122)
# ('lh_G_postcentral_area', False, 95)
# ('lh_G_precentral_area', False, 68)
# ('lh_G_precuneus_area', False, 53)
# ('lh_G_rectus_area', False, 17)
# ('lh_G_subcallosal_area', False, 40)
# ('lh_G_temp_sup-G_T_transv_area', False, 89)
# ('lh_G_temp_sup-Lateral_area', False, 23)
# ('lh_G_temp_sup-Plan_polar_area', False, 48)
# ('lh_G_temp_sup-Plan_tempo_area', False, 51)
# ('lh_G_temporal_inf_area', False, 86)
# ('lh_G_temporal_middle_area', False, 18)
# ('lh_Lat_Fis-ant-Horizont_area', False, 52)
# ('lh_Lat_Fis-ant-Vertical_area', False, 14)
# ('lh_Lat_Fis-post_area', False, 127)
# ('lh_Pole_occipital_area', False, 87)
# ('lh_Pole_temporal_area', False, 85)
# ('lh_S_calcarine_area', False, 132)
# ('lh_S_central_area', False, 135)
# ('lh_S_cingul-Marginalis_area', False, 72)
# ('lh_S_circular_insula_ant_area', False, 33)
# ('lh_S_circular_insula_inf_area', True, 1)
# ('lh_S_circular_insula_sup_area', False, 7)
# ('lh_S_collat_transv_ant_area', False, 117)
# ('lh_S_collat_transv_post_area', False, 49)
# ('lh_S_front_inf_area', False, 16)
# ('lh_S_front_middle_area', False, 80)
# ('lh_S_front_sup_area', False, 112)
# ('lh_S_interm_prim-Jensen_area', False, 111)
# ('lh_S_intrapariet_and_P_trans_area', False, 9)
# ('lh_S_oc_middle_and_Lunatus_area', False, 3)
# ('lh_S_oc_sup_and_transversal_area', False, 29)
# ('lh_S_occipital_ant_area', False, 90)
# ('lh_S_oc-temp_lat_area', False, 8)
# ('lh_S_oc-temp_med_and_Lingual_area', False, 57)
# ('lh_S_orbital_lateral_area', False, 141)
# ('lh_S_orbital_med-olfact_area', False, 32)
# ('lh_S_orbital-H_Shaped_area', False, 70)
# ('lh_S_parieto_occipital_area', False, 92)
# ('lh_S_pericallosal_area', False, 69)
# ('lh_S_postcentral_area', False, 121)
# ('lh_S_precentral-inf-part_area', False, 139)
# ('lh_S_precentral-sup-part_area', False, 102)
# ('lh_S_suborbital_area', False, 84)
# ('lh_S_subparietal_area', False, 21)
# ('lh_S_temporal_inf_area', False, 59)
# ('lh_S_temporal_sup_area', False, 134)
# ('lh_S_temporal_transverse_area', False, 97)
# ('rh_G_and_S_frontomargin_area', False, 106)
# ('rh_G_and_S_occipital_inf_area', False, 67)
# ('rh_G_and_S_paracentral_area', False, 65)
# ('rh_G_and_S_subcentral_area', False, 24)
# ('rh_G_and_S_transv_frontopol_area', False, 26)
# ('rh_G_and_S_cingul-Ant_area', False, 100)
# ('rh_G_and_S_cingul-Mid-Ant_area', False, 4)
# ('rh_G_and_S_cingul-Mid-Post_area', False, 99)
# ('rh_G_cingul-Post-dorsal_area', False, 28)
# ('rh_G_cingul-Post-ventral_area', False, 61)
# ('rh_G_cuneus_area', False, 66)
# ('rh_G_front_inf-Opercular_area', False, 126)
# ('rh_G_front_inf-Orbital_area', False, 75)
# ('rh_G_front_inf-Triangul_area', False, 39)
# ('rh_G_front_middle_area', False, 64)
# ('rh_G_front_sup_area', False, 124)
# ('rh_G_Ins_lg_and_S_cent_ins_area', False, 55)
# ('rh_G_insular_short_area', False, 20)
# ('rh_G_occipital_middle_area', False, 38)
# ('rh_G_occipital_sup_area', False, 131)
# ('rh_G_oc-temp_lat-fusifor_area', False, 116)
# ('rh_G_oc-temp_med-Lingual_area', False, 109)
# ('rh_G_oc-temp_med-Parahip_area', False, 94)
# ('rh_G_orbital_area', False, 30)
# ('rh_G_pariet_inf-Angular_area', False, 137)
# ('rh_G_pariet_inf-Supramar_area', False, 128)
# ('rh_G_parietal_sup_area', False, 81)
# ('rh_G_postcentral_area', False, 43)
# ('rh_G_precentral_area', False, 41)
# ('rh_G_precuneus_area', False, 113)
# ('rh_G_rectus_area', False, 133)
# ('rh_G_subcallosal_area', False, 98)
# ('rh_G_temp_sup-G_T_transv_area', False, 88)
# ('rh_G_temp_sup-Lateral_area', False, 58)
# ('rh_G_temp_sup-Plan_polar_area', False, 62)
# ('rh_G_temp_sup-Plan_tempo_area', False, 60)
# ('rh_G_temporal_inf_area', False, 46)
# ('rh_G_temporal_middle_area', False, 47)
# ('rh_Lat_Fis-ant-Horizont_area', False, 103)
# ('rh_Lat_Fis-ant-Vertical_area', False, 78)
# ('rh_Lat_Fis-post_area', False, 130)
# ('rh_Pole_occipital_area', False, 82)
# ('rh_Pole_temporal_area', False, 93)
# ('rh_S_calcarine_area', False, 5)
# ('rh_S_central_area', False, 63)
# ('rh_S_cingul-Marginalis_area', False, 54)
# ('rh_S_circular_insula_ant_area', False, 73)
# ('rh_S_circular_insula_inf_area', False, 27)
# ('rh_S_circular_insula_sup_area', False, 125)
# ('rh_S_collat_transv_ant_area', False, 31)
# ('rh_S_collat_transv_post_area', False, 13)
# ('rh_S_front_inf_area', False, 2)
# ('rh_S_front_middle_area', False, 138)
# ('rh_S_front_sup_area', False, 37)
# ('rh_S_interm_prim-Jensen_area', False, 77)
# ('rh_S_intrapariet_and_P_trans_area', False, 143)
# ('rh_S_oc_middle_and_Lunatus_area', False, 123)
# ('rh_S_oc_sup_and_transversal_area', False, 19)
# ('rh_S_occipital_ant_area', False, 79)
# ('rh_S_oc-temp_lat_area', False, 56)
# ('rh_S_oc-temp_med_and_Lingual_area', False, 74)
# ('rh_S_orbital_lateral_area', False, 107)
# ('rh_S_orbital_med-olfact_area', False, 110)
# ('rh_S_orbital-H_Shaped_area', False, 25)
# ('rh_S_parieto_occipital_area', False, 136)
# ('rh_S_pericallosal_area', False, 119)
# ('rh_S_postcentral_area', False, 42)
# ('rh_S_precentral-inf-part_area', False, 101)
# ('rh_S_precentral-sup-part_area', False, 35)
# ('rh_S_suborbital_area', False, 6)
# ('rh_S_subparietal_area', False, 15)
# ('rh_S_temporal_inf_area', False, 146)
# ('rh_S_temporal_sup_area', False, 120)
# ('rh_S_temporal_transverse_area', False, 11)
# end with: area
#
# ('lh_G_and_S_frontomargin_meancurv', True, 1)
# ('lh_G_and_S_occipital_inf_meancurv', True, 1)
# ('lh_G_and_S_paracentral_meancurv', True, 1)
# ('lh_G_and_S_subcentral_meancurv', True, 1)
# ('lh_G_and_S_transv_frontopol_meancurv', True, 1)
# ('lh_G_and_S_cingul-Ant_meancurv', True, 1)
# ('lh_G_and_S_cingul-Mid-Ant_meancurv', False, 37)
# ('lh_G_and_S_cingul-Mid-Post_meancurv', False, 49)
# ('lh_G_cingul-Post-dorsal_meancurv', True, 1)
# ('lh_G_cingul-Post-ventral_meancurv', False, 22)
# ('lh_G_cuneus_meancurv', False, 65)
# ('lh_G_front_inf-Opercular_meancurv', True, 1)
# ('lh_G_front_inf-Orbital_meancurv', True, 1)
# ('lh_G_front_inf-Triangul_meancurv', True, 1)
# ('lh_G_front_middle_meancurv', True, 1)
# ('lh_G_front_sup_meancurv', True, 1)
# ('lh_G_Ins_lg_and_S_cent_ins_meancurv', True, 1)
# ('lh_G_insular_short_meancurv', True, 1)
# ('lh_G_occipital_middle_meancurv', False, 7)
# ('lh_G_occipital_sup_meancurv', True, 1)
# ('lh_G_oc-temp_lat-fusifor_meancurv', False, 19)
# ('lh_G_oc-temp_med-Lingual_meancurv', False, 32)
# ('lh_G_oc-temp_med-Parahip_meancurv', True, 1)
# ('lh_G_orbital_meancurv', True, 1)
# ('lh_G_pariet_inf-Angular_meancurv', True, 1)
# ('lh_G_pariet_inf-Supramar_meancurv', True, 1)
# ('lh_G_parietal_sup_meancurv', True, 1)
# ('lh_G_postcentral_meancurv', True, 1)
# ('lh_G_precentral_meancurv', True, 1)
# ('lh_G_precuneus_meancurv', False, 3)
# ('lh_G_rectus_meancurv', False, 39)
# ('lh_G_subcallosal_meancurv', False, 44)
# ('lh_G_temp_sup-G_T_transv_meancurv', True, 1)
# ('lh_G_temp_sup-Lateral_meancurv', False, 61)
# ('lh_G_temp_sup-Plan_polar_meancurv', True, 1)
# ('lh_G_temp_sup-Plan_tempo_meancurv', False, 28)
# ('lh_G_temporal_inf_meancurv', True, 1)
# ('lh_G_temporal_middle_meancurv', False, 52)
# ('lh_Lat_Fis-ant-Horizont_meancurv', True, 1)
# ('lh_Lat_Fis-ant-Vertical_meancurv', True, 1)
# ('lh_Lat_Fis-post_meancurv', False, 26)
# ('lh_Pole_occipital_meancurv', True, 1)
# ('lh_Pole_temporal_meancurv', True, 1)
# ('lh_S_calcarine_meancurv', False, 13)
# ('lh_S_central_meancurv', False, 59)
# ('lh_S_cingul-Marginalis_meancurv', False, 70)
# ('lh_S_circular_insula_ant_meancurv', False, 54)
# ('lh_S_circular_insula_inf_meancurv', False, 27)
# ('lh_S_circular_insula_sup_meancurv', True, 1)
# ('lh_S_collat_transv_ant_meancurv', False, 42)
# ('lh_S_collat_transv_post_meancurv', True, 1)
# ('lh_S_front_inf_meancurv', False, 62)
# ('lh_S_front_middle_meancurv', True, 1)
# ('lh_S_front_sup_meancurv', False, 15)
# ('lh_S_interm_prim-Jensen_meancurv', False, 58)
# ('lh_S_intrapariet_and_P_trans_meancurv', False, 57)
# ('lh_S_oc_middle_and_Lunatus_meancurv', True, 1)
# ('lh_S_oc_sup_and_transversal_meancurv', False, 17)
# ('lh_S_occipital_ant_meancurv', False, 64)
# ('lh_S_oc-temp_lat_meancurv', False, 43)
# ('lh_S_oc-temp_med_and_Lingual_meancurv', True, 1)
# ('lh_S_orbital_lateral_meancurv', False, 25)
# ('lh_S_orbital_med-olfact_meancurv', False, 45)
# ('lh_S_orbital-H_Shaped_meancurv', False, 36)
# ('lh_S_parieto_occipital_meancurv', False, 23)
# ('lh_S_pericallosal_meancurv', True, 1)
# ('lh_S_postcentral_meancurv', False, 12)
# ('lh_S_precentral-inf-part_meancurv', False, 60)
# ('lh_S_precentral-sup-part_meancurv', False, 74)
# ('lh_S_suborbital_meancurv', True, 1)
# ('lh_S_subparietal_meancurv', False, 14)
# ('lh_S_temporal_inf_meancurv', False, 35)
# ('lh_S_temporal_sup_meancurv', False, 34)
# ('lh_S_temporal_transverse_meancurv', False, 21)
# ('rh_G_and_S_frontomargin_meancurv', True, 1)
# ('rh_G_and_S_occipital_inf_meancurv', True, 1)
# ('rh_G_and_S_paracentral_meancurv', False, 41)
# ('rh_G_and_S_subcentral_meancurv', False, 5)
# ('rh_G_and_S_transv_frontopol_meancurv', True, 1)
# ('rh_G_and_S_cingul-Ant_meancurv', False, 56)
# ('rh_G_and_S_cingul-Mid-Ant_meancurv', True, 1)
# ('rh_G_and_S_cingul-Mid-Post_meancurv', False, 47)
# ('rh_G_cingul-Post-dorsal_meancurv', True, 1)
# ('rh_G_cingul-Post-ventral_meancurv', False, 10)
# ('rh_G_cuneus_meancurv', False, 63)
# ('rh_G_front_inf-Opercular_meancurv', True, 1)
# ('rh_G_front_inf-Orbital_meancurv', True, 1)
# ('rh_G_front_inf-Triangul_meancurv', True, 1)
# ('rh_G_front_middle_meancurv', True, 1)
# ('rh_G_front_sup_meancurv', True, 1)
# ('rh_G_Ins_lg_and_S_cent_ins_meancurv', True, 1)
# ('rh_G_insular_short_meancurv', True, 1)
# ('rh_G_occipital_middle_meancurv', False, 2)
# ('rh_G_occipital_sup_meancurv', False, 4)
# ('rh_G_oc-temp_lat-fusifor_meancurv', False, 48)
# ('rh_G_oc-temp_med-Lingual_meancurv', False, 55)
# ('rh_G_oc-temp_med-Parahip_meancurv', True, 1)
# ('rh_G_orbital_meancurv', True, 1)
# ('rh_G_pariet_inf-Angular_meancurv', True, 1)
# ('rh_G_pariet_inf-Supramar_meancurv', True, 1)
# ('rh_G_parietal_sup_meancurv', False, 20)
# ('rh_G_postcentral_meancurv', True, 1)
# ('rh_G_precentral_meancurv', True, 1)
# ('rh_G_precuneus_meancurv', True, 1)
# ('rh_G_rectus_meancurv', True, 1)
# ('rh_G_subcallosal_meancurv', True, 1)
# ('rh_G_temp_sup-G_T_transv_meancurv', True, 1)
# ('rh_G_temp_sup-Lateral_meancurv', False, 69)
# ('rh_G_temp_sup-Plan_polar_meancurv', True, 1)
# ('rh_G_temp_sup-Plan_tempo_meancurv', True, 1)
# ('rh_G_temporal_inf_meancurv', False, 76)
# ('rh_G_temporal_middle_meancurv', False, 71)
# ('rh_Lat_Fis-ant-Horizont_meancurv', False, 11)
# ('rh_Lat_Fis-ant-Vertical_meancurv', False, 68)
# ('rh_Lat_Fis-post_meancurv', False, 75)
# ('rh_Pole_occipital_meancurv', False, 72)
# ('rh_Pole_temporal_meancurv', True, 1)
# ('rh_S_calcarine_meancurv', True, 1)
# ('rh_S_central_meancurv', False, 46)
# ('rh_S_cingul-Marginalis_meancurv', False, 50)
# ('rh_S_circular_insula_ant_meancurv', False, 16)
# ('rh_S_circular_insula_inf_meancurv', False, 51)
# ('rh_S_circular_insula_sup_meancurv', True, 1)
# ('rh_S_collat_transv_ant_meancurv', True, 1)
# ('rh_S_collat_transv_post_meancurv', False, 67)
# ('rh_S_front_inf_meancurv', False, 18)
# ('rh_S_front_middle_meancurv', True, 1)
# ('rh_S_front_sup_meancurv', False, 6)
# ('rh_S_interm_prim-Jensen_meancurv', False, 33)
# ('rh_S_intrapariet_and_P_trans_meancurv', False, 30)
# ('rh_S_oc_middle_and_Lunatus_meancurv', False, 8)
# ('rh_S_oc_sup_and_transversal_meancurv', False, 73)
# ('rh_S_occipital_ant_meancurv', True, 1)
# ('rh_S_oc-temp_lat_meancurv', True, 1)
# ('rh_S_oc-temp_med_and_Lingual_meancurv', True, 1)
# ('rh_S_orbital_lateral_meancurv', False, 9)
# ('rh_S_orbital_med-olfact_meancurv', False, 40)
# ('rh_S_orbital-H_Shaped_meancurv', False, 31)
# ('rh_S_parieto_occipital_meancurv', True, 1)
# ('rh_S_pericallosal_meancurv', True, 1)
# ('rh_S_postcentral_meancurv', False, 66)
# ('rh_S_precentral-inf-part_meancurv', False, 24)
# ('rh_S_precentral-sup-part_meancurv', True, 1)
# ('rh_S_suborbital_meancurv', True, 1)
# ('rh_S_subparietal_meancurv', True, 1)
# ('rh_S_temporal_inf_meancurv', False, 29)
# ('rh_S_temporal_sup_meancurv', False, 53)
# ('rh_S_temporal_transverse_meancurv', False, 38)
# end with: meancurv
#
# ('lh_G_and_S_frontomargin_thickness', False, 65)
# ('lh_G_and_S_occipital_inf_thickness', True, 1)
# ('lh_G_and_S_paracentral_thickness', False, 21)
# ('lh_G_and_S_subcentral_thickness', False, 41)
# ('lh_G_and_S_transv_frontopol_thickness', True, 1)
# ('lh_G_and_S_cingul-Ant_thickness', False, 88)
# ('lh_G_and_S_cingul-Mid-Ant_thickness', True, 1)
# ('lh_G_and_S_cingul-Mid-Post_thickness', False, 80)
# ('lh_G_cingul-Post-dorsal_thickness', False, 4)
# ('lh_G_cingul-Post-ventral_thickness', False, 83)
# ('lh_G_cuneus_thickness', True, 1)
# ('lh_G_front_inf-Opercular_thickness', True, 1)
# ('lh_G_front_inf-Orbital_thickness', True, 1)
# ('lh_G_front_inf-Triangul_thickness', True, 1)
# ('lh_G_front_middle_thickness', False, 34)
# ('lh_G_front_sup_thickness', False, 86)
# ('lh_G_Ins_lg_and_S_cent_ins_thickness', False, 27)
# ('lh_G_insular_short_thickness', False, 71)
# ('lh_G_occipital_middle_thickness', False, 7)
# ('lh_G_occipital_sup_thickness', False, 18)
# ('lh_G_oc-temp_lat-fusifor_thickness', False, 53)
# ('lh_G_oc-temp_med-Lingual_thickness', False, 20)
# ('lh_G_oc-temp_med-Parahip_thickness', False, 90)
# ('lh_G_orbital_thickness', False, 49)
# ('lh_G_pariet_inf-Angular_thickness', True, 1)
# ('lh_G_pariet_inf-Supramar_thickness', False, 76)
# ('lh_G_parietal_sup_thickness', False, 89)
# ('lh_G_postcentral_thickness', False, 35)
# ('lh_G_precentral_thickness', True, 1)
# ('lh_G_precuneus_thickness', False, 13)
# ('lh_G_rectus_thickness', True, 1)
# ('lh_G_subcallosal_thickness', False, 100)
# ('lh_G_temp_sup-G_T_transv_thickness', True, 1)
# ('lh_G_temp_sup-Lateral_thickness', False, 102)
# ('lh_G_temp_sup-Plan_polar_thickness', True, 1)
# ('lh_G_temp_sup-Plan_tempo_thickness', True, 1)
# ('lh_G_temporal_inf_thickness', False, 45)
# ('lh_G_temporal_middle_thickness', False, 107)
# ('lh_Lat_Fis-ant-Horizont_thickness', False, 72)
# ('lh_Lat_Fis-ant-Vertical_thickness', False, 98)
# ('lh_Lat_Fis-post_thickness', True, 1)
# ('lh_Pole_occipital_thickness', False, 82)
# ('lh_Pole_temporal_thickness', False, 17)
# ('lh_S_calcarine_thickness', False, 23)
# ('lh_S_central_thickness', False, 22)
# ('lh_S_cingul-Marginalis_thickness', False, 54)
# ('lh_S_circular_insula_ant_thickness', False, 30)
# ('lh_S_circular_insula_inf_thickness', False, 67)
# ('lh_S_circular_insula_sup_thickness', False, 96)
# ('lh_S_collat_transv_ant_thickness', False, 10)
# ('lh_S_collat_transv_post_thickness', True, 1)
# ('lh_S_front_inf_thickness', False, 28)
# ('lh_S_front_middle_thickness', True, 1)
# ('lh_S_front_sup_thickness', False, 58)
# ('lh_S_interm_prim-Jensen_thickness', False, 78)
# ('lh_S_intrapariet_and_P_trans_thickness', False, 19)
# ('lh_S_oc_middle_and_Lunatus_thickness', False, 37)
# ('lh_S_oc_sup_and_transversal_thickness', True, 1)
# ('lh_S_occipital_ant_thickness', False, 61)
# ('lh_S_oc-temp_lat_thickness', False, 33)
# ('lh_S_oc-temp_med_and_Lingual_thickness', False, 95)
# ('lh_S_orbital_lateral_thickness', False, 42)
# ('lh_S_orbital_med-olfact_thickness', False, 2)
# ('lh_S_orbital-H_Shaped_thickness', False, 48)
# ('lh_S_parieto_occipital_thickness', False, 56)
# ('lh_S_pericallosal_thickness', False, 59)
# ('lh_S_postcentral_thickness', True, 1)
# ('lh_S_precentral-inf-part_thickness', False, 99)
# ('lh_S_precentral-sup-part_thickness', True, 1)
# ('lh_S_suborbital_thickness', True, 1)
# ('lh_S_subparietal_thickness', True, 1)
# ('lh_S_temporal_inf_thickness', False, 87)
# ('lh_S_temporal_sup_thickness', False, 97)
# ('lh_S_temporal_transverse_thickness', False, 32)
# ('rh_G_and_S_frontomargin_thickness', False, 85)
# ('rh_G_and_S_occipital_inf_thickness', False, 84)
# ('rh_G_and_S_paracentral_thickness', False, 38)
# ('rh_G_and_S_subcentral_thickness', True, 1)
# ('rh_G_and_S_transv_frontopol_thickness', False, 3)
# ('rh_G_and_S_cingul-Ant_thickness', False, 60)
# ('rh_G_and_S_cingul-Mid-Ant_thickness', True, 1)
# ('rh_G_and_S_cingul-Mid-Post_thickness', False, 8)
# ('rh_G_cingul-Post-dorsal_thickness', False, 15)
# ('rh_G_cingul-Post-ventral_thickness', True, 1)
# ('rh_G_cuneus_thickness', True, 1)
# ('rh_G_front_inf-Opercular_thickness', False, 106)
# ('rh_G_front_inf-Orbital_thickness', False, 91)
# ('rh_G_front_inf-Triangul_thickness', True, 1)
# ('rh_G_front_middle_thickness', True, 1)
# ('rh_G_front_sup_thickness', True, 1)
# ('rh_G_Ins_lg_and_S_cent_ins_thickness', False, 93)
# ('rh_G_insular_short_thickness', True, 1)
# ('rh_G_occipital_middle_thickness', False, 25)
# ('rh_G_occipital_sup_thickness', False, 52)
# ('rh_G_oc-temp_lat-fusifor_thickness', False, 29)
# ('rh_G_oc-temp_med-Lingual_thickness', True, 1)
# ('rh_G_oc-temp_med-Parahip_thickness', False, 63)
# ('rh_G_orbital_thickness', False, 50)
# ('rh_G_pariet_inf-Angular_thickness', False, 31)
# ('rh_G_pariet_inf-Supramar_thickness', True, 1)
# ('rh_G_parietal_sup_thickness', True, 1)
# ('rh_G_postcentral_thickness', True, 1)
# ('rh_G_precentral_thickness', False, 75)
# ('rh_G_precuneus_thickness', False, 47)
# ('rh_G_rectus_thickness', True, 1)
# ('rh_G_subcallosal_thickness', False, 81)
# ('rh_G_temp_sup-G_T_transv_thickness', False, 12)
# ('rh_G_temp_sup-Lateral_thickness', False, 70)
# ('rh_G_temp_sup-Plan_polar_thickness', False, 79)
# ('rh_G_temp_sup-Plan_tempo_thickness', False, 73)
# ('rh_G_temporal_inf_thickness', False, 44)
# ('rh_G_temporal_middle_thickness', False, 26)
# ('rh_Lat_Fis-ant-Horizont_thickness', False, 51)
# ('rh_Lat_Fis-ant-Vertical_thickness', False, 64)
# ('rh_Lat_Fis-post_thickness', False, 92)
# ('rh_Pole_occipital_thickness', False, 69)
# ('rh_Pole_temporal_thickness', True, 1)
# ('rh_S_calcarine_thickness', True, 1)
# ('rh_S_central_thickness', False, 9)
# ('rh_S_cingul-Marginalis_thickness', False, 94)
# ('rh_S_circular_insula_ant_thickness', False, 16)
# ('rh_S_circular_insula_inf_thickness', True, 1)
# ('rh_S_circular_insula_sup_thickness', True, 1)
# ('rh_S_collat_transv_ant_thickness', False, 57)
# ('rh_S_collat_transv_post_thickness', False, 24)
# ('rh_S_front_inf_thickness', False, 55)
# ('rh_S_front_middle_thickness', True, 1)
# ('rh_S_front_sup_thickness', True, 1)
# ('rh_S_interm_prim-Jensen_thickness', False, 62)
# ('rh_S_intrapariet_and_P_trans_thickness', False, 46)
# ('rh_S_oc_middle_and_Lunatus_thickness', False, 101)
# ('rh_S_oc_sup_and_transversal_thickness', False, 6)
# ('rh_S_occipital_ant_thickness', False, 74)
# ('rh_S_oc-temp_lat_thickness', False, 39)
# ('rh_S_oc-temp_med_and_Lingual_thickness', False, 11)
# ('rh_S_orbital_lateral_thickness', False, 68)
# ('rh_S_orbital_med-olfact_thickness', False, 104)
# ('rh_S_orbital-H_Shaped_thickness', True, 1)
# ('rh_S_parieto_occipital_thickness', False, 14)
# ('rh_S_pericallosal_thickness', True, 1)
# ('rh_S_postcentral_thickness', False, 40)
# ('rh_S_precentral-inf-part_thickness', False, 36)
# ('rh_S_precentral-sup-part_thickness', False, 105)
# ('rh_S_suborbital_thickness', False, 43)
# ('rh_S_subparietal_thickness', False, 103)
# ('rh_S_temporal_inf_thickness', False, 66)
# ('rh_S_temporal_sup_thickness', False, 5)
# ('rh_S_temporal_transverse_thickness', False, 77)
# end with: thickness
#
# ('lh_G_and_S_frontomargin_volume', True, 1)
# ('lh_G_and_S_occipital_inf_volume', True, 1)
# ('lh_G_and_S_paracentral_volume', True, 1)
# ('lh_G_and_S_subcentral_volume', True, 1)
# ('lh_G_and_S_transv_frontopol_volume', True, 1)
# ('lh_G_and_S_cingul-Ant_volume', True, 1)
# ('lh_G_and_S_cingul-Mid-Ant_volume', True, 1)
# ('lh_G_and_S_cingul-Mid-Post_volume', True, 1)
# ('lh_G_cingul-Post-dorsal_volume', True, 1)
# ('lh_G_cingul-Post-ventral_volume', True, 1)
# ('lh_G_cuneus_volume', True, 1)
# ('lh_G_front_inf-Opercular_volume', True, 1)
# ('lh_G_front_inf-Orbital_volume', True, 1)
# ('lh_G_front_inf-Triangul_volume', True, 1)
# ('lh_G_front_middle_volume', False, 12)
# ('lh_G_front_sup_volume', False, 2)
# ('lh_G_Ins_lg_and_S_cent_ins_volume', True, 1)
# ('lh_G_insular_short_volume', True, 1)
# ('lh_G_occipital_middle_volume', True, 1)
# ('lh_G_occipital_sup_volume', False, 8)
# ('lh_G_oc-temp_lat-fusifor_volume', True, 1)
# ('lh_G_oc-temp_med-Lingual_volume', True, 1)
# ('lh_G_oc-temp_med-Parahip_volume', True, 1)
# ('lh_G_orbital_volume', True, 1)
# ('lh_G_pariet_inf-Angular_volume', True, 1)
# ('lh_G_pariet_inf-Supramar_volume', True, 1)
# ('lh_G_parietal_sup_volume', True, 1)
# ('lh_G_postcentral_volume', True, 1)
# ('lh_G_precentral_volume', True, 1)
# ('lh_G_precuneus_volume', True, 1)
# ('lh_G_rectus_volume', True, 1)
# ('lh_G_subcallosal_volume', True, 1)
# ('lh_G_temp_sup-G_T_transv_volume', True, 1)
# ('lh_G_temp_sup-Lateral_volume', True, 1)
# ('lh_G_temp_sup-Plan_polar_volume', True, 1)
# ('lh_G_temp_sup-Plan_tempo_volume', True, 1)
# ('lh_G_temporal_inf_volume', True, 1)
# ('lh_G_temporal_middle_volume', True, 1)
# ('lh_Lat_Fis-ant-Horizont_volume', True, 1)
# ('lh_Lat_Fis-ant-Vertical_volume', True, 1)
# ('lh_Lat_Fis-post_volume', True, 1)
# ('lh_Pole_occipital_volume', True, 1)
# ('lh_Pole_temporal_volume', True, 1)
# ('lh_S_calcarine_volume', True, 1)
# ('lh_S_central_volume', True, 1)
# ('lh_S_cingul-Marginalis_volume', True, 1)
# ('lh_S_circular_insula_ant_volume', True, 1)
# ('lh_S_circular_insula_inf_volume', True, 1)
# ('lh_S_circular_insula_sup_volume', True, 1)
# ('lh_S_collat_transv_ant_volume', True, 1)
# ('lh_S_collat_transv_post_volume', True, 1)
# ('lh_S_front_inf_volume', True, 1)
# ('lh_S_front_middle_volume', True, 1)
# ('lh_S_front_sup_volume', True, 1)
# ('lh_S_interm_prim-Jensen_volume', True, 1)
# ('lh_S_intrapariet_and_P_trans_volume', False, 5)
# ('lh_S_oc_middle_and_Lunatus_volume', True, 1)
# ('lh_S_oc_sup_and_transversal_volume', True, 1)
# ('lh_S_occipital_ant_volume', True, 1)
# ('lh_S_oc-temp_lat_volume', False, 9)
# ('lh_S_oc-temp_med_and_Lingual_volume', True, 1)
# ('lh_S_orbital_lateral_volume', True, 1)
# ('lh_S_orbital_med-olfact_volume', True, 1)
# ('lh_S_orbital-H_Shaped_volume', True, 1)
# ('lh_S_parieto_occipital_volume', True, 1)
# ('lh_S_pericallosal_volume', True, 1)
# ('lh_S_postcentral_volume', True, 1)
# ('lh_S_precentral-inf-part_volume', True, 1)
# ('lh_S_precentral-sup-part_volume', False, 10)
# ('lh_S_suborbital_volume', True, 1)
# ('lh_S_subparietal_volume', True, 1)
# ('lh_S_temporal_inf_volume', True, 1)
# ('lh_S_temporal_sup_volume', False, 7)
# ('lh_S_temporal_transverse_volume', True, 1)
# ('rh_G_and_S_frontomargin_volume', True, 1)
# ('rh_G_and_S_occipital_inf_volume', True, 1)
# ('rh_G_and_S_paracentral_volume', True, 1)
# ('rh_G_and_S_subcentral_volume', True, 1)
# ('rh_G_and_S_transv_frontopol_volume', True, 1)
# ('rh_G_and_S_cingul-Ant_volume', True, 1)
# ('rh_G_and_S_cingul-Mid-Ant_volume', True, 1)
# ('rh_G_and_S_cingul-Mid-Post_volume', True, 1)
# ('rh_G_cingul-Post-dorsal_volume', True, 1)
# ('rh_G_cingul-Post-ventral_volume', True, 1)
# ('rh_G_cuneus_volume', True, 1)
# ('rh_G_front_inf-Opercular_volume', True, 1)
# ('rh_G_front_inf-Orbital_volume', True, 1)
# ('rh_G_front_inf-Triangul_volume', False, 4)
# ('rh_G_front_middle_volume', True, 1)
# ('rh_G_front_sup_volume', True, 1)
# ('rh_G_Ins_lg_and_S_cent_ins_volume', True, 1)
# ('rh_G_insular_short_volume', True, 1)
# ('rh_G_occipital_middle_volume', True, 1)
# ('rh_G_occipital_sup_volume', True, 1)
# ('rh_G_oc-temp_lat-fusifor_volume', True, 1)
# ('rh_G_oc-temp_med-Lingual_volume', True, 1)
# ('rh_G_oc-temp_med-Parahip_volume', True, 1)
# ('rh_G_orbital_volume', False, 11)
# ('rh_G_pariet_inf-Angular_volume', True, 1)
# ('rh_G_pariet_inf-Supramar_volume', True, 1)
# ('rh_G_parietal_sup_volume', True, 1)
# ('rh_G_postcentral_volume', True, 1)
# ('rh_G_precentral_volume', True, 1)
# ('rh_G_precuneus_volume', True, 1)
# ('rh_G_rectus_volume', True, 1)
# ('rh_G_subcallosal_volume', True, 1)
# ('rh_G_temp_sup-G_T_transv_volume', True, 1)
# ('rh_G_temp_sup-Lateral_volume', True, 1)
# ('rh_G_temp_sup-Plan_polar_volume', True, 1)
# ('rh_G_temp_sup-Plan_tempo_volume', True, 1)
# ('rh_G_temporal_inf_volume', True, 1)
# ('rh_G_temporal_middle_volume', True, 1)
# ('rh_Lat_Fis-ant-Horizont_volume', True, 1)
# ('rh_Lat_Fis-ant-Vertical_volume', True, 1)
# ('rh_Lat_Fis-post_volume', False, 3)
# ('rh_Pole_occipital_volume', True, 1)
# ('rh_Pole_temporal_volume', True, 1)
# ('rh_S_calcarine_volume', True, 1)
# ('rh_S_central_volume', True, 1)
# ('rh_S_cingul-Marginalis_volume', True, 1)
# ('rh_S_circular_insula_ant_volume', True, 1)
# ('rh_S_circular_insula_inf_volume', True, 1)
# ('rh_S_circular_insula_sup_volume', True, 1)
# ('rh_S_collat_transv_ant_volume', True, 1)
# ('rh_S_collat_transv_post_volume', True, 1)
# ('rh_S_front_inf_volume', True, 1)
# ('rh_S_front_middle_volume', True, 1)
# ('rh_S_front_sup_volume', True, 1)
# ('rh_S_interm_prim-Jensen_volume', True, 1)
# ('rh_S_intrapariet_and_P_trans_volume', True, 1)
# ('rh_S_oc_middle_and_Lunatus_volume', True, 1)
# ('rh_S_oc_sup_and_transversal_volume', True, 1)
# ('rh_S_occipital_ant_volume', True, 1)
# ('rh_S_oc-temp_lat_volume', True, 1)
# ('rh_S_oc-temp_med_and_Lingual_volume', True, 1)
# ('rh_S_orbital_lateral_volume', True, 1)
# ('rh_S_orbital_med-olfact_volume', True, 1)
# ('rh_S_orbital-H_Shaped_volume', True, 1)
# ('rh_S_parieto_occipital_volume', True, 1)
# ('rh_S_pericallosal_volume', True, 1)
# ('rh_S_postcentral_volume', True, 1)
# ('rh_S_precentral-inf-part_volume', True, 1)
# ('rh_S_precentral-sup-part_volume', True, 1)
# ('rh_S_suborbital_volume', True, 1)
# ('rh_S_subparietal_volume', False, 6)
# ('rh_S_temporal_inf_volume', True, 1)
# ('rh_S_temporal_sup_volume', True, 1)
# ('rh_S_temporal_transverse_volume', True, 1)
# end with: volume

# %%
for ranking in rankings:
    data = ranking['data']
    data.sort_values("Support", axis=0, ascending= True, inplace= True)

rankings[0]['data']
# Out:
#                                   Ranking Support
# Name
# lh_S_circular_insula_inf_area        True       1
# lh_G_and_S_cingul-Mid-Ant_area       True       1
# lh_G_oc-temp_med-Parahip_area        True       1
# rh_S_front_inf_area                 False       2
# lh_S_oc_middle_and_Lunatus_area     False       3
# ...                                   ...     ...
# lh_G_front_middle_area              False     142
# rh_S_intrapariet_and_P_trans_area   False     143
# lh_G_cingul-Post-ventral_area       False     144
# lh_G_pariet_inf-Angular_area        False     145
# rh_S_temporal_inf_area              False     146
#
# [148 rows x 2 columns]

# %% [markdown]
# # Save the Rankings on CSVs

# %%
for ranking in rankings:
    data = ranking['data']
    name = ranking['name']
    data.to_csv("output/SVMRFE (Support)" + name + ".csv")
    data[data["Support"]==1].to_csv("output/SVMRFE (Support - 1)" + name + ".csv")
