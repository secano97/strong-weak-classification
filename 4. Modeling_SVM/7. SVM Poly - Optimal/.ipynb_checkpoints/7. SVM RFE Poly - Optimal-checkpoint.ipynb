# %% [markdown]
# # <center> <b> <h1>   SVM RFE Non Linear - Optimal </h1></b></center>

# %%
import matplotlib.pyplot as plt
import numpy as np 

from sklearn.feature_selection import SelectFromModel
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix
import joblib

from sklearn.svm import SVC
from sklearn.svm import LinearSVC
from sklearn.feature_selection import RFECV

from sklearn import datasets, svm
from sklearn.model_selection import StratifiedKFold, GridSearchCV
from sklearn.metrics import classification_report

import pickle

import pandas as pd
import itertools

PATH_DATASETS = "../../2_Data_preparation/2_Split_Raw_Datasets/output/"
PATH_RANKINGS = "../1. SVM RFE (All features)/csv/"
PATH_MAX_ITER = "../1. SVM RFE (All features)/output/"

# %%
def readCsvs(split):
    datasets = []
    constant1 = 'X_'
    constant2 = '_' + split
    features = ['area', 'meancurv', 'thickness', 'volume']

    for feature in features:
        df = pd.read_csv(PATH_DATASETS + constant1 + feature + constant2 +'.csv', index_col=0)
        datasets.append({'name': feature, 'data': df})
    return datasets

# %%
def readRankings(ranking = 0):
    datasets = []
    constants = ['used_regions_normalized_convergence_',
                 'used_regions_normalized_highest_']    
    
    features = ['area', 'meancurv', 'thickness', 'volume']

    for feature in features:
        df = pd.read_csv(PATH_RANKINGS + constants[ranking] + feature +'.csv', index_col=0)
        datasets.append({'name': feature, 'data': df})
    return datasets

# %%
def readMaxIter(i = 0):
    constants = ['models_info_list_convergence_normalized',
                 'models_info_list_accuracy_normalized',
                 'models_info_list_convergence', 
                 'models_info_list_highest_acc' ]
    
    inputFile = PATH_MAX_ITER + constants[i] +'.data'
    fd = open(inputFile, 'rb')
    data = pickle.load(fd)
    return data

# %% [markdown]
# # 1. Prepare the data

# %%
df_X_tr = readCsvs('train')
df_X_tr[0]['data'].shape
# Out:
# (550, 148)

# %%
df_y_train = pd.read_csv(PATH_DATASETS + 'Y_train.csv', index_col = 0)
df_y_train.shape
# Out:
# (550, 1)

# %%
df_X_val = readCsvs('validate')
df_X_val[0]['data'].shape
# Out:
# (338, 148)

# %%
df_y_val = pd.read_csv(PATH_DATASETS + 'Y_validate.csv', index_col = 0)
df_y_val.shape
# Out:
# (338, 1)

# %% [markdown]
# ####  Convergence

# %%
#0 for normalized convergence and 1 for normalized highest accuracy
support_data_convergence = readRankings()
support_data_convergence[0]['data'].head()
# Out:
#                                Ranking  Support
# Name
# lh_G_and_S_frontomargin_area         1     True
# rh_S_orbital-H_Shaped_area           1     True
# lh_S_circular_insula_sup_area        1     True
# lh_S_collat_transv_ant_area          1     True
# rh_S_collat_transv_post_area         1     True

# %% [markdown]
# # Normalize Data

# %%
for df_tr, df_val in zip(df_X_tr, df_X_val):
    train = df_tr['data']
    val = df_val['data']
    
    normal_tr = (train - train.mean(axis=0))/train.std()
    normal_val = (val - val.mean(axis=0))/val.std()
    
    df_tr['data'] = normal_tr
    df_val['data'] = normal_val

# %%
df_X_tr[0]['data'].head()
# Out:
#         lh_G_and_S_frontomargin_area  lh_G_and_S_occipital_inf_area  \
# 414229                      0.309576                       0.224009
# 541943                     -0.076249                       0.352958
# 206525                      1.821379                       1.235757
# 146533                      1.656025                       0.933225
# 194746                     -0.918764                       0.273605
#
#         lh_G_and_S_paracentral_area  lh_G_and_S_subcentral_area  \
# 414229                     1.107822                    1.264846
# 541943                    -0.262869                    0.412671
# 206525                     0.221342                    1.378470
# 146533                     1.614382                   -0.344818
# 194746                    -0.657688                   -0.067072
#
#         lh_G_and_S_transv_frontopol_area  lh_G_and_S_cingul-Ant_area  \
# 414229                         -0.053643                    0.447702
# 541943                         -0.728809                   -0.994397
# 206525                          0.139262                    2.154329
# 146533                          0.310732                    2.457255
# 194746                         -0.621640                   -0.772536
#
#         lh_G_and_S_cingul-Mid-Ant_area  lh_G_and_S_cingul-Mid-Post_area  \
# 414229                        0.977805                         0.781809
# 541943                       -0.892543                        -0.132296
# 206525                        0.479456                         0.281038
# 146533                        1.002415                         0.519500
# 194746                       -0.486481                         0.137961
#
#         lh_G_cingul-Post-dorsal_area  lh_G_cingul-Post-ventral_area  ...  \
# 414229                     -0.594180                      -0.761092  ...
# 541943                     -1.093925                      -0.695517  ...
# 206525                     -0.560107                       1.577744  ...
# 146533                     -0.491960                       0.054950  ...
# 194746                     -0.491960                      -0.476934  ...
#
#         rh_S_parieto_occipital_area  rh_S_pericallosal_area  \
# 414229                     0.221416                0.381852
# 541943                     0.137165                3.971853
# 206525                     2.151850                1.750859
# 146533                     1.305682                0.006832
# 194746                     0.016284                0.451031
#
#         rh_S_postcentral_area  rh_S_precentral-inf-part_area  \
# 414229              -0.114597                       1.444931
# 541943              -0.980071                      -0.602848
# 206525               1.175570                      -0.649815
# 146533               0.956788                      -0.161354
# 194746              -0.143553                      -0.969194
#
#         rh_S_precentral-sup-part_area  rh_S_suborbital_area  \
# 414229                       0.064915             -0.435619
# 541943                      -1.391463              1.763449
# 206525                       1.331331              1.466642
# 146533                       2.071697             -0.044374
# 194746                      -0.388072             -1.069706
#
#         rh_S_subparietal_area  rh_S_temporal_inf_area  rh_S_temporal_sup_area  \
# 414229              -1.510187               -0.718114               -1.077114
# 541943              -0.070073                1.569996               -1.101390
# 206525               1.690066                1.386581                2.638980
# 146533              -0.431244               -0.846505                1.292596
# 194746              -0.536396                0.079744               -0.490755
#
#         rh_S_temporal_transverse_area
# 414229                      -0.575371
# 541943                      -0.732631
# 206525                       0.660251
# 146533                      -1.024687
# 194746                      -0.081122
#
# [5 rows x 148 columns]

# %% [markdown]
# ### selecting the regions that are in the ranking

# %%
import copy
def selectRegionsRaking(ranking_list):
    new_df_X_tr = copy.deepcopy(df_X_tr)
    new_df_X_val = copy.deepcopy(df_X_val)
    
    for feature_train, feature_validate, ranking in zip(new_df_X_tr, new_df_X_val, ranking_list):
        data_train = feature_train['data']
        data_validate = feature_validate['data']
        data_ranking = ranking['data']

        feature_train['data'] = data_train[data_ranking.index.values].copy()
        feature_validate['data'] = data_validate[data_ranking.index.values].copy()
    
    return new_df_X_tr, new_df_X_val

# %%
df_X_tr_convergence, df_X_val_convergence = selectRegionsRaking(support_data_convergence)
df_X_tr_convergence[0]['data'].shape
# Out:
# (550, 11)

# %%
#0 and 1 for normalized convergence and accuracy respectively
#2 and 3 for not normalized
model_info_list_convergence_normalized = readMaxIter(0)

# %%
model_info_list_convergence_normalized[0]['data'][0]
# Out:
# 2900

# %% [markdown]
# # 2. Grid Search CV

# %%
# defining parameter range 
param_grid = {'C': [0.1, 1, 10, 100, 1000],  
              'gamma': [1, 0.1, 0.01, 0.001, 0.0001], 
              'kernel': ['rbf']}

scores = ['precision', 'recall']
best_configuration = []
for feature_train, feature_validate, model_info in zip(df_X_tr, df_X_val, model_info_list_convergence_normalized):
    
    data_name = feature_train['name']
    data_train = feature_train['data']
    data_validate = feature_validate['data']
    max_iter = model_info['data'][0]
    
    
    print("******************************** GRID SEARCH FOR: " + data_name + " ******************************")
    
    for score in scores:
        print("# Tuning hyper-parameters for %s" % score)
        print()
        
        grid = GridSearchCV(SVC(max_iter = max_iter, cache_size = 2000), param_grid, refit = True, verbose = 3, n_jobs=-1, scoring='%s_macro' % score, cv=5) 
  
        # fitting the model for grid search 
        grid.fit(data_train, df_y_train.values.ravel())
        
        if (score == 'precision'):
            best_configuration.append({'name' : data_name, 'data' : grid.best_params_})

        print("Best parameters set found on development set: ", grid.best_params_)
        print("Grid scores on develpment set: ")
        means = grid.cv_results_['mean_test_score']
        stds = grid.cv_results_['std_test_score']
        for mean, std, params in zip(means, stds, grid.cv_results_['params']):
            print("%0.3f (+/-%0.03f) for %r"
                 %(mean, std * 2, params))

        print("Detailed Classification Report: ")
        print("the model is trained on the full development set.")
        print("The scores are computed on the full evaluation set.")
        y_true, y_pred = df_y_val, grid.predict(data_validate)
        print(classification_report(y_true,y_pred))
        print()
# Out:
# ******************************** GRID SEARCH FOR: area ******************************
# # Tuning hyper-parameters for precision
#
# Fitting 5 folds for each of 25 candidates, totalling 125 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  62 out of 125 | elapsed:    1.0s remaining:    1.1s
# [Parallel(n_jobs=-1)]: Done 104 out of 125 | elapsed:    1.5s remaining:    0.3s
# [Parallel(n_jobs=-1)]: Done 125 out of 125 | elapsed:    1.6s finished
# Best parameters set found on development set:  {'C': 0.1, 'gamma': 0.0001, 'kernel': 'rbf'}
# Grid scores on develpment set:
# 0.575 (+/-0.074) for {'C': 0.1, 'gamma': 1, 'kernel': 'rbf'}
# 0.552 (+/-0.497) for {'C': 0.1, 'gamma': 0.1, 'kernel': 'rbf'}
# 0.699 (+/-0.098) for {'C': 0.1, 'gamma': 0.01, 'kernel': 'rbf'}
# 0.685 (+/-0.118) for {'C': 0.1, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.723 (+/-0.094) for {'C': 0.1, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.451 (+/-0.493) for {'C': 1, 'gamma': 1, 'kernel': 'rbf'}
# 0.599 (+/-0.098) for {'C': 1, 'gamma': 0.1, 'kernel': 'rbf'}
# 0.692 (+/-0.096) for {'C': 1, 'gamma': 0.01, 'kernel': 'rbf'}
# 0.706 (+/-0.092) for {'C': 1, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.689 (+/-0.129) for {'C': 1, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.552 (+/-0.494) for {'C': 10, 'gamma': 1, 'kernel': 'rbf'}
# 0.598 (+/-0.123) for {'C': 10, 'gamma': 0.1, 'kernel': 'rbf'}
# 0.662 (+/-0.114) for {'C': 10, 'gamma': 0.01, 'kernel': 'rbf'}
# 0.687 (+/-0.103) for {'C': 10, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.691 (+/-0.098) for {'C': 10, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.552 (+/-0.494) for {'C': 100, 'gamma': 1, 'kernel': 'rbf'}
# 0.598 (+/-0.123) for {'C': 100, 'gamma': 0.1, 'kernel': 'rbf'}
# 0.662 (+/-0.114) for {'C': 100, 'gamma': 0.01, 'kernel': 'rbf'}
# 0.613 (+/-0.112) for {'C': 100, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.673 (+/-0.093) for {'C': 100, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.552 (+/-0.494) for {'C': 1000, 'gamma': 1, 'kernel': 'rbf'}
# 0.598 (+/-0.123) for {'C': 1000, 'gamma': 0.1, 'kernel': 'rbf'}
# 0.662 (+/-0.114) for {'C': 1000, 'gamma': 0.01, 'kernel': 'rbf'}
# 0.606 (+/-0.100) for {'C': 1000, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.631 (+/-0.132) for {'C': 1000, 'gamma': 0.0001, 'kernel': 'rbf'}
# Detailed Classification Report:
# the model is trained on the full development set.
# The scores are computed on the full evaluation set.
#               precision    recall  f1-score   support
#
#           -1       0.62      0.89      0.73       173
#            1       0.79      0.43      0.56       165
#
#     accuracy                           0.67       338
#    macro avg       0.70      0.66      0.64       338
# weighted avg       0.70      0.67      0.65       338
#
#
# # Tuning hyper-parameters for recall
#
# Fitting 5 folds for each of 25 candidates, totalling 125 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  62 out of 125 | elapsed:    1.2s remaining:    1.2s
# [Parallel(n_jobs=-1)]: Done 104 out of 125 | elapsed:    1.6s remaining:    0.3s
# [Parallel(n_jobs=-1)]: Done 125 out of 125 | elapsed:    1.8s finished
# Best parameters set found on development set:  {'C': 0.1, 'gamma': 0.01, 'kernel': 'rbf'}
# Grid scores on develpment set:
# 0.575 (+/-0.073) for {'C': 0.1, 'gamma': 1, 'kernel': 'rbf'}
# 0.509 (+/-0.033) for {'C': 0.1, 'gamma': 0.1, 'kernel': 'rbf'}
# 0.698 (+/-0.097) for {'C': 0.1, 'gamma': 0.01, 'kernel': 'rbf'}
# 0.680 (+/-0.112) for {'C': 0.1, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.678 (+/-0.077) for {'C': 0.1, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.505 (+/-0.015) for {'C': 1, 'gamma': 1, 'kernel': 'rbf'}
# 0.565 (+/-0.082) for {'C': 1, 'gamma': 0.1, 'kernel': 'rbf'}
# 0.687 (+/-0.091) for {'C': 1, 'gamma': 0.01, 'kernel': 'rbf'}
# 0.696 (+/-0.084) for {'C': 1, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.685 (+/-0.125) for {'C': 1, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.509 (+/-0.016) for {'C': 10, 'gamma': 1, 'kernel': 'rbf'}
# 0.567 (+/-0.099) for {'C': 10, 'gamma': 0.1, 'kernel': 'rbf'}
# 0.662 (+/-0.113) for {'C': 10, 'gamma': 0.01, 'kernel': 'rbf'}
# 0.684 (+/-0.100) for {'C': 10, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.687 (+/-0.095) for {'C': 10, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.509 (+/-0.016) for {'C': 100, 'gamma': 1, 'kernel': 'rbf'}
# 0.567 (+/-0.099) for {'C': 100, 'gamma': 0.1, 'kernel': 'rbf'}
# 0.662 (+/-0.113) for {'C': 100, 'gamma': 0.01, 'kernel': 'rbf'}
# 0.613 (+/-0.112) for {'C': 100, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.671 (+/-0.090) for {'C': 100, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.509 (+/-0.016) for {'C': 1000, 'gamma': 1, 'kernel': 'rbf'}
# 0.567 (+/-0.099) for {'C': 1000, 'gamma': 0.1, 'kernel': 'rbf'}
# 0.662 (+/-0.113) for {'C': 1000, 'gamma': 0.01, 'kernel': 'rbf'}
# 0.605 (+/-0.100) for {'C': 1000, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.629 (+/-0.129) for {'C': 1000, 'gamma': 0.0001, 'kernel': 'rbf'}
# Detailed Classification Report:
# the model is trained on the full development set.
# The scores are computed on the full evaluation set.
#               precision    recall  f1-score   support
#
#           -1       0.73      0.74      0.73       173
#            1       0.72      0.71      0.72       165
#
#     accuracy                           0.72       338
#    macro avg       0.72      0.72      0.72       338
# weighted avg       0.72      0.72      0.72       338
#
#
# ******************************** GRID SEARCH FOR: meancurv ******************************
# # Tuning hyper-parameters for precision
#
# Fitting 5 folds for each of 25 candidates, totalling 125 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  62 out of 125 | elapsed:    1.2s remaining:    1.2s
# [Parallel(n_jobs=-1)]: Done 104 out of 125 | elapsed:    1.6s remaining:    0.3s
# [Parallel(n_jobs=-1)]: Done 125 out of 125 | elapsed:    1.8s finished
# Best parameters set found on development set:  {'C': 10, 'gamma': 0.0001, 'kernel': 'rbf'}
# Grid scores on develpment set:
# 0.542 (+/-0.073) for {'C': 0.1, 'gamma': 1, 'kernel': 'rbf'}
# 0.620 (+/-0.399) for {'C': 0.1, 'gamma': 0.1, 'kernel': 'rbf'}
# 0.591 (+/-0.092) for {'C': 0.1, 'gamma': 0.01, 'kernel': 'rbf'}
# 0.576 (+/-0.093) for {'C': 0.1, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.582 (+/-0.116) for {'C': 0.1, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.451 (+/-0.493) for {'C': 1, 'gamma': 1, 'kernel': 'rbf'}
# 0.634 (+/-0.102) for {'C': 1, 'gamma': 0.1, 'kernel': 'rbf'}
# 0.652 (+/-0.073) for {'C': 1, 'gamma': 0.01, 'kernel': 'rbf'}
# 0.656 (+/-0.055) for {'C': 1, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.582 (+/-0.116) for {'C': 1, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.629 (+/-0.391) for {'C': 10, 'gamma': 1, 'kernel': 'rbf'}
# 0.622 (+/-0.106) for {'C': 10, 'gamma': 0.1, 'kernel': 'rbf'}
# 0.652 (+/-0.038) for {'C': 10, 'gamma': 0.01, 'kernel': 'rbf'}
# 0.646 (+/-0.064) for {'C': 10, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.667 (+/-0.089) for {'C': 10, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.629 (+/-0.391) for {'C': 100, 'gamma': 1, 'kernel': 'rbf'}
# 0.622 (+/-0.106) for {'C': 100, 'gamma': 0.1, 'kernel': 'rbf'}
# 0.652 (+/-0.038) for {'C': 100, 'gamma': 0.01, 'kernel': 'rbf'}
# 0.615 (+/-0.070) for {'C': 100, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.639 (+/-0.067) for {'C': 100, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.629 (+/-0.391) for {'C': 1000, 'gamma': 1, 'kernel': 'rbf'}
# 0.622 (+/-0.106) for {'C': 1000, 'gamma': 0.1, 'kernel': 'rbf'}
# 0.652 (+/-0.038) for {'C': 1000, 'gamma': 0.01, 'kernel': 'rbf'}
# 0.615 (+/-0.060) for {'C': 1000, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.617 (+/-0.080) for {'C': 1000, 'gamma': 0.0001, 'kernel': 'rbf'}
# Detailed Classification Report:
# the model is trained on the full development set.
# The scores are computed on the full evaluation set.
#               precision    recall  f1-score   support
#
#           -1       0.71      0.69      0.70       173
#            1       0.68      0.70      0.69       165
#
#     accuracy                           0.70       338
#    macro avg       0.70      0.70      0.70       338
# weighted avg       0.70      0.70      0.70       338
#
#
# # Tuning hyper-parameters for recall
#
# Fitting 5 folds for each of 25 candidates, totalling 125 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  62 out of 125 | elapsed:    1.0s remaining:    1.1s
# [Parallel(n_jobs=-1)]: Done 104 out of 125 | elapsed:    1.6s remaining:    0.3s
# [Parallel(n_jobs=-1)]: Done 125 out of 125 | elapsed:    1.8s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# Best parameters set found on development set:  {'C': 10, 'gamma': 0.0001, 'kernel': 'rbf'}
# Grid scores on develpment set:
# 0.542 (+/-0.072) for {'C': 0.1, 'gamma': 1, 'kernel': 'rbf'}
# 0.527 (+/-0.047) for {'C': 0.1, 'gamma': 0.1, 'kernel': 'rbf'}
# 0.585 (+/-0.080) for {'C': 0.1, 'gamma': 0.01, 'kernel': 'rbf'}
# 0.575 (+/-0.090) for {'C': 0.1, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.575 (+/-0.114) for {'C': 0.1, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.505 (+/-0.015) for {'C': 1, 'gamma': 1, 'kernel': 'rbf'}
# 0.605 (+/-0.087) for {'C': 1, 'gamma': 0.1, 'kernel': 'rbf'}
# 0.651 (+/-0.073) for {'C': 1, 'gamma': 0.01, 'kernel': 'rbf'}
# 0.653 (+/-0.056) for {'C': 1, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.575 (+/-0.114) for {'C': 1, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.515 (+/-0.019) for {'C': 10, 'gamma': 1, 'kernel': 'rbf'}
# 0.600 (+/-0.091) for {'C': 10, 'gamma': 0.1, 'kernel': 'rbf'}
# 0.651 (+/-0.037) for {'C': 10, 'gamma': 0.01, 'kernel': 'rbf'}
# 0.645 (+/-0.065) for {'C': 10, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.665 (+/-0.088) for {'C': 10, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.515 (+/-0.019) for {'C': 100, 'gamma': 1, 'kernel': 'rbf'}
# 0.600 (+/-0.091) for {'C': 100, 'gamma': 0.1, 'kernel': 'rbf'}
# 0.651 (+/-0.037) for {'C': 100, 'gamma': 0.01, 'kernel': 'rbf'}
# 0.615 (+/-0.071) for {'C': 100, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.638 (+/-0.066) for {'C': 100, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.515 (+/-0.019) for {'C': 1000, 'gamma': 1, 'kernel': 'rbf'}
# 0.600 (+/-0.091) for {'C': 1000, 'gamma': 0.1, 'kernel': 'rbf'}
# 0.651 (+/-0.037) for {'C': 1000, 'gamma': 0.01, 'kernel': 'rbf'}
# 0.615 (+/-0.060) for {'C': 1000, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.616 (+/-0.081) for {'C': 1000, 'gamma': 0.0001, 'kernel': 'rbf'}
# Detailed Classification Report:
# the model is trained on the full development set.
# The scores are computed on the full evaluation set.
#               precision    recall  f1-score   support
#
#           -1       0.71      0.69      0.70       173
#            1       0.68      0.70      0.69       165
#
#     accuracy                           0.70       338
#    macro avg       0.70      0.70      0.70       338
# weighted avg       0.70      0.70      0.70       338
#
#
# ******************************** GRID SEARCH FOR: thickness ******************************
# # Tuning hyper-parameters for precision
#
# Fitting 5 folds for each of 25 candidates, totalling 125 fits
# [Parallel(n_jobs=-1)]: Done  62 out of 125 | elapsed:    1.1s remaining:    1.1s
# [Parallel(n_jobs=-1)]: Done 104 out of 125 | elapsed:    1.6s remaining:    0.3s
# [Parallel(n_jobs=-1)]: Done 125 out of 125 | elapsed:    1.8s finished
# Best parameters set found on development set:  {'C': 1, 'gamma': 0.001, 'kernel': 'rbf'}
# Grid scores on develpment set:
# 0.558 (+/-0.141) for {'C': 0.1, 'gamma': 1, 'kernel': 'rbf'}
# 0.511 (+/-0.322) for {'C': 0.1, 'gamma': 0.1, 'kernel': 'rbf'}
# 0.607 (+/-0.083) for {'C': 0.1, 'gamma': 0.01, 'kernel': 'rbf'}
# 0.603 (+/-0.087) for {'C': 0.1, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.575 (+/-0.144) for {'C': 0.1, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.451 (+/-0.492) for {'C': 1, 'gamma': 1, 'kernel': 'rbf'}
# 0.556 (+/-0.069) for {'C': 1, 'gamma': 0.1, 'kernel': 'rbf'}
# 0.650 (+/-0.048) for {'C': 1, 'gamma': 0.01, 'kernel': 'rbf'}
# 0.665 (+/-0.040) for {'C': 1, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.568 (+/-0.155) for {'C': 1, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.601 (+/-0.404) for {'C': 10, 'gamma': 1, 'kernel': 'rbf'}
# 0.562 (+/-0.055) for {'C': 10, 'gamma': 0.1, 'kernel': 'rbf'}
# 0.664 (+/-0.072) for {'C': 10, 'gamma': 0.01, 'kernel': 'rbf'}
# 0.645 (+/-0.045) for {'C': 10, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.663 (+/-0.031) for {'C': 10, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.601 (+/-0.404) for {'C': 100, 'gamma': 1, 'kernel': 'rbf'}
# 0.562 (+/-0.055) for {'C': 100, 'gamma': 0.1, 'kernel': 'rbf'}
# 0.664 (+/-0.072) for {'C': 100, 'gamma': 0.01, 'kernel': 'rbf'}
# 0.634 (+/-0.079) for {'C': 100, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.644 (+/-0.036) for {'C': 100, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.601 (+/-0.404) for {'C': 1000, 'gamma': 1, 'kernel': 'rbf'}
# 0.562 (+/-0.055) for {'C': 1000, 'gamma': 0.1, 'kernel': 'rbf'}
# 0.664 (+/-0.072) for {'C': 1000, 'gamma': 0.01, 'kernel': 'rbf'}
# 0.639 (+/-0.081) for {'C': 1000, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.608 (+/-0.057) for {'C': 1000, 'gamma': 0.0001, 'kernel': 'rbf'}
# Detailed Classification Report:
# the model is trained on the full development set.
# The scores are computed on the full evaluation set.
#               precision    recall  f1-score   support
#
#           -1       0.79      0.75      0.77       173
#            1       0.75      0.79      0.77       165
#
#     accuracy                           0.77       338
#    macro avg       0.77      0.77      0.77       338
# weighted avg       0.77      0.77      0.77       338
#
#
# # Tuning hyper-parameters for recall
#
# Fitting 5 folds for each of 25 candidates, totalling 125 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  62 out of 125 | elapsed:    1.0s remaining:    1.0s
# [Parallel(n_jobs=-1)]: Done 104 out of 125 | elapsed:    1.5s remaining:    0.3s
# [Parallel(n_jobs=-1)]: Done 125 out of 125 | elapsed:    1.8s finished
# Best parameters set found on development set:  {'C': 1, 'gamma': 0.001, 'kernel': 'rbf'}
# Grid scores on develpment set:
# 0.558 (+/-0.140) for {'C': 0.1, 'gamma': 1, 'kernel': 'rbf'}
# 0.507 (+/-0.031) for {'C': 0.1, 'gamma': 0.1, 'kernel': 'rbf'}
# 0.605 (+/-0.083) for {'C': 0.1, 'gamma': 0.01, 'kernel': 'rbf'}
# 0.596 (+/-0.075) for {'C': 0.1, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.549 (+/-0.114) for {'C': 0.1, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.504 (+/-0.009) for {'C': 1, 'gamma': 1, 'kernel': 'rbf'}
# 0.547 (+/-0.062) for {'C': 1, 'gamma': 0.1, 'kernel': 'rbf'}
# 0.649 (+/-0.047) for {'C': 1, 'gamma': 0.01, 'kernel': 'rbf'}
# 0.664 (+/-0.038) for {'C': 1, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.547 (+/-0.117) for {'C': 1, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.504 (+/-0.015) for {'C': 10, 'gamma': 1, 'kernel': 'rbf'}
# 0.551 (+/-0.048) for {'C': 10, 'gamma': 0.1, 'kernel': 'rbf'}
# 0.662 (+/-0.071) for {'C': 10, 'gamma': 0.01, 'kernel': 'rbf'}
# 0.644 (+/-0.044) for {'C': 10, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.662 (+/-0.029) for {'C': 10, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.504 (+/-0.015) for {'C': 100, 'gamma': 1, 'kernel': 'rbf'}
# 0.551 (+/-0.048) for {'C': 100, 'gamma': 0.1, 'kernel': 'rbf'}
# 0.662 (+/-0.071) for {'C': 100, 'gamma': 0.01, 'kernel': 'rbf'}
# 0.633 (+/-0.080) for {'C': 100, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.644 (+/-0.035) for {'C': 100, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.504 (+/-0.015) for {'C': 1000, 'gamma': 1, 'kernel': 'rbf'}
# 0.551 (+/-0.048) for {'C': 1000, 'gamma': 0.1, 'kernel': 'rbf'}
# 0.662 (+/-0.071) for {'C': 1000, 'gamma': 0.01, 'kernel': 'rbf'}
# 0.638 (+/-0.082) for {'C': 1000, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.607 (+/-0.058) for {'C': 1000, 'gamma': 0.0001, 'kernel': 'rbf'}
# Detailed Classification Report:
# the model is trained on the full development set.
# The scores are computed on the full evaluation set.
#               precision    recall  f1-score   support
#
#           -1       0.79      0.75      0.77       173
#            1       0.75      0.79      0.77       165
#
#     accuracy                           0.77       338
#    macro avg       0.77      0.77      0.77       338
# weighted avg       0.77      0.77      0.77       338
#
#
# ******************************** GRID SEARCH FOR: volume ******************************
# # Tuning hyper-parameters for precision
#
# Fitting 5 folds for each of 25 candidates, totalling 125 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  62 out of 125 | elapsed:    1.1s remaining:    1.1s
# [Parallel(n_jobs=-1)]: Done 104 out of 125 | elapsed:    1.6s remaining:    0.3s
# [Parallel(n_jobs=-1)]: Done 125 out of 125 | elapsed:    1.8s finished
# Best parameters set found on development set:  {'C': 1, 'gamma': 0.001, 'kernel': 'rbf'}
# Grid scores on develpment set:
# 0.609 (+/-0.124) for {'C': 0.1, 'gamma': 1, 'kernel': 'rbf'}
# 0.512 (+/-0.119) for {'C': 0.1, 'gamma': 0.1, 'kernel': 'rbf'}
# 0.691 (+/-0.095) for {'C': 0.1, 'gamma': 0.01, 'kernel': 'rbf'}
# 0.696 (+/-0.106) for {'C': 0.1, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.714 (+/-0.074) for {'C': 0.1, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.367 (+/-0.292) for {'C': 1, 'gamma': 1, 'kernel': 'rbf'}
# 0.610 (+/-0.063) for {'C': 1, 'gamma': 0.1, 'kernel': 'rbf'}
# 0.705 (+/-0.110) for {'C': 1, 'gamma': 0.01, 'kernel': 'rbf'}
# 0.717 (+/-0.106) for {'C': 1, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.697 (+/-0.090) for {'C': 1, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.384 (+/-0.329) for {'C': 10, 'gamma': 1, 'kernel': 'rbf'}
# 0.612 (+/-0.053) for {'C': 10, 'gamma': 0.1, 'kernel': 'rbf'}
# 0.668 (+/-0.101) for {'C': 10, 'gamma': 0.01, 'kernel': 'rbf'}
# 0.683 (+/-0.060) for {'C': 10, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.716 (+/-0.111) for {'C': 10, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.384 (+/-0.329) for {'C': 100, 'gamma': 1, 'kernel': 'rbf'}
# 0.612 (+/-0.053) for {'C': 100, 'gamma': 0.1, 'kernel': 'rbf'}
# 0.668 (+/-0.101) for {'C': 100, 'gamma': 0.01, 'kernel': 'rbf'}
# 0.635 (+/-0.050) for {'C': 100, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.663 (+/-0.074) for {'C': 100, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.384 (+/-0.329) for {'C': 1000, 'gamma': 1, 'kernel': 'rbf'}
# 0.612 (+/-0.053) for {'C': 1000, 'gamma': 0.1, 'kernel': 'rbf'}
# 0.668 (+/-0.101) for {'C': 1000, 'gamma': 0.01, 'kernel': 'rbf'}
# 0.630 (+/-0.063) for {'C': 1000, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.644 (+/-0.033) for {'C': 1000, 'gamma': 0.0001, 'kernel': 'rbf'}
# Detailed Classification Report:
# the model is trained on the full development set.
# The scores are computed on the full evaluation set.
#               precision    recall  f1-score   support
#
#           -1       0.72      0.79      0.75       173
#            1       0.76      0.68      0.72       165
#
#     accuracy                           0.74       338
#    macro avg       0.74      0.74      0.74       338
# weighted avg       0.74      0.74      0.74       338
#
#
# # Tuning hyper-parameters for recall
#
# Fitting 5 folds for each of 25 candidates, totalling 125 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  62 out of 125 | elapsed:    1.1s remaining:    1.1s
# [Parallel(n_jobs=-1)]: Done 104 out of 125 | elapsed:    1.5s remaining:    0.3s
# [Parallel(n_jobs=-1)]: Done 125 out of 125 | elapsed:    1.7s finished
# Best parameters set found on development set:  {'C': 10, 'gamma': 0.0001, 'kernel': 'rbf'}
# Grid scores on develpment set:
# 0.609 (+/-0.124) for {'C': 0.1, 'gamma': 1, 'kernel': 'rbf'}
# 0.507 (+/-0.031) for {'C': 0.1, 'gamma': 0.1, 'kernel': 'rbf'}
# 0.689 (+/-0.094) for {'C': 0.1, 'gamma': 0.01, 'kernel': 'rbf'}
# 0.691 (+/-0.103) for {'C': 0.1, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.684 (+/-0.066) for {'C': 0.1, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.502 (+/-0.007) for {'C': 1, 'gamma': 1, 'kernel': 'rbf'}
# 0.575 (+/-0.048) for {'C': 1, 'gamma': 0.1, 'kernel': 'rbf'}
# 0.700 (+/-0.105) for {'C': 1, 'gamma': 0.01, 'kernel': 'rbf'}
# 0.711 (+/-0.100) for {'C': 1, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.691 (+/-0.088) for {'C': 1, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.504 (+/-0.009) for {'C': 10, 'gamma': 1, 'kernel': 'rbf'}
# 0.576 (+/-0.042) for {'C': 10, 'gamma': 0.1, 'kernel': 'rbf'}
# 0.667 (+/-0.101) for {'C': 10, 'gamma': 0.01, 'kernel': 'rbf'}
# 0.680 (+/-0.056) for {'C': 10, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.713 (+/-0.108) for {'C': 10, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.504 (+/-0.009) for {'C': 100, 'gamma': 1, 'kernel': 'rbf'}
# 0.576 (+/-0.042) for {'C': 100, 'gamma': 0.1, 'kernel': 'rbf'}
# 0.667 (+/-0.101) for {'C': 100, 'gamma': 0.01, 'kernel': 'rbf'}
# 0.635 (+/-0.049) for {'C': 100, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.662 (+/-0.075) for {'C': 100, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.504 (+/-0.009) for {'C': 1000, 'gamma': 1, 'kernel': 'rbf'}
# 0.576 (+/-0.042) for {'C': 1000, 'gamma': 0.1, 'kernel': 'rbf'}
# 0.667 (+/-0.101) for {'C': 1000, 'gamma': 0.01, 'kernel': 'rbf'}
# 0.629 (+/-0.063) for {'C': 1000, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.642 (+/-0.032) for {'C': 1000, 'gamma': 0.0001, 'kernel': 'rbf'}
# Detailed Classification Report:
# the model is trained on the full development set.
# The scores are computed on the full evaluation set.
#               precision    recall  f1-score   support
#
#           -1       0.75      0.78      0.76       173
#            1       0.76      0.73      0.74       165
#
#     accuracy                           0.75       338
#    macro avg       0.75      0.75      0.75       338
# weighted avg       0.75      0.75      0.75       338

# %%
param_grid = {'C': [0.001, 0.01, 0.1, 1, 10, 100, 1000], 'gamma' : [0.001, 0.01, 0.1, 1, 10, 100, 1000]} # posible mejoría con elbow metod
scores = ['precision', 'recall']
best_configuration_2 = []

for feature_train, feature_validate, model_info in zip(df_X_tr, df_X_val, model_info_list_convergence_normalized):
    
    data_name = feature_train['name']
    data_train = feature_train['data']
    data_validate = feature_validate['data']
    max_iter = model_info['data'][0]
    
    print("******************************** GRID SEARCH FOR: " + data_name + " ******************************")

    for score in scores:
        print("# Tuning hyper-parameters for %s" % score)
        print()

        svc = SVC(C = "scale", kernel = 'rbf', gamma = "scale", max_iter = max_iter, cache_size = 2000)
        clf = GridSearchCV(svc, param_grid, verbose=0, n_jobs=-1, scoring='%s_macro' % score, cv = 5)
        clf.fit(data_train, df_y_train['class'].values)
        
        if (score == 'precision'):
            best_configuration_2.append({'name' : data_name, 'data' : clf.best_params_})

        print("Best parameters set found on development set: ", clf.best_params_)
        print("Grid scores on develpment set: ")
        means = clf.cv_results_['mean_test_score']
        stds = clf.cv_results_['std_test_score']
        for mean, std, params in zip(means, stds, clf.cv_results_['params']):
            print("%0.3f (+/-%0.03f) for %r"
                 %(mean, std * 2, params))

        print("Detailed Classification Report: ")
        print("the model is trained on the full development set.")
        print("The scores are computed on the full evaluation set.")
        y_true, y_pred = df_y_val, clf.predict(data_validate)
        print(classification_report(y_true,y_pred))
        print()
# Out:
# ******************************** GRID SEARCH FOR: area ******************************
# # Tuning hyper-parameters for precision
#
# Best parameters set found on development set:  {'C': 1, 'gamma': 0.001}
# Grid scores on develpment set:
# 0.696 (+/-0.085) for {'C': 0.001, 'gamma': 0.001}
# 0.703 (+/-0.092) for {'C': 0.001, 'gamma': 0.01}
# 0.552 (+/-0.497) for {'C': 0.001, 'gamma': 0.1}
# 0.575 (+/-0.074) for {'C': 0.001, 'gamma': 1}
# 0.250 (+/-0.000) for {'C': 0.001, 'gamma': 10}
# 0.250 (+/-0.000) for {'C': 0.001, 'gamma': 100}
# 0.250 (+/-0.000) for {'C': 0.001, 'gamma': 1000}
# 0.696 (+/-0.085) for {'C': 0.01, 'gamma': 0.001}
# 0.703 (+/-0.092) for {'C': 0.01, 'gamma': 0.01}
# 0.552 (+/-0.497) for {'C': 0.01, 'gamma': 0.1}
# 0.575 (+/-0.074) for {'C': 0.01, 'gamma': 1}
# 0.250 (+/-0.000) for {'C': 0.01, 'gamma': 10}
# 0.250 (+/-0.000) for {'C': 0.01, 'gamma': 100}
# 0.250 (+/-0.000) for {'C': 0.01, 'gamma': 1000}
# 0.685 (+/-0.118) for {'C': 0.1, 'gamma': 0.001}
# 0.699 (+/-0.098) for {'C': 0.1, 'gamma': 0.01}
# 0.552 (+/-0.497) for {'C': 0.1, 'gamma': 0.1}
# 0.575 (+/-0.074) for {'C': 0.1, 'gamma': 1}
# 0.250 (+/-0.000) for {'C': 0.1, 'gamma': 10}
# 0.250 (+/-0.000) for {'C': 0.1, 'gamma': 100}
# 0.250 (+/-0.000) for {'C': 0.1, 'gamma': 1000}
# 0.706 (+/-0.092) for {'C': 1, 'gamma': 0.001}
# 0.692 (+/-0.096) for {'C': 1, 'gamma': 0.01}
# 0.599 (+/-0.098) for {'C': 1, 'gamma': 0.1}
# 0.451 (+/-0.493) for {'C': 1, 'gamma': 1}
# 0.250 (+/-0.000) for {'C': 1, 'gamma': 10}
# 0.250 (+/-0.000) for {'C': 1, 'gamma': 100}
# 0.250 (+/-0.000) for {'C': 1, 'gamma': 1000}
# 0.687 (+/-0.103) for {'C': 10, 'gamma': 0.001}
# 0.662 (+/-0.114) for {'C': 10, 'gamma': 0.01}
# 0.598 (+/-0.123) for {'C': 10, 'gamma': 0.1}
# 0.552 (+/-0.494) for {'C': 10, 'gamma': 1}
# 0.250 (+/-0.000) for {'C': 10, 'gamma': 10}
# 0.250 (+/-0.000) for {'C': 10, 'gamma': 100}
# 0.250 (+/-0.000) for {'C': 10, 'gamma': 1000}
# 0.613 (+/-0.112) for {'C': 100, 'gamma': 0.001}
# 0.662 (+/-0.114) for {'C': 100, 'gamma': 0.01}
# 0.598 (+/-0.123) for {'C': 100, 'gamma': 0.1}
# 0.552 (+/-0.494) for {'C': 100, 'gamma': 1}
# 0.250 (+/-0.000) for {'C': 100, 'gamma': 10}
# 0.250 (+/-0.000) for {'C': 100, 'gamma': 100}
# 0.250 (+/-0.000) for {'C': 100, 'gamma': 1000}
# 0.606 (+/-0.100) for {'C': 1000, 'gamma': 0.001}
# 0.662 (+/-0.114) for {'C': 1000, 'gamma': 0.01}
# 0.598 (+/-0.123) for {'C': 1000, 'gamma': 0.1}
# 0.552 (+/-0.494) for {'C': 1000, 'gamma': 1}
# 0.250 (+/-0.000) for {'C': 1000, 'gamma': 10}
# 0.250 (+/-0.000) for {'C': 1000, 'gamma': 100}
# 0.250 (+/-0.000) for {'C': 1000, 'gamma': 1000}
# Detailed Classification Report:
# the model is trained on the full development set.
# The scores are computed on the full evaluation set.
#               precision    recall  f1-score   support
#
#           -1       0.68      0.80      0.74       173
#            1       0.74      0.61      0.67       165
#
#     accuracy                           0.71       338
#    macro avg       0.71      0.70      0.70       338
# weighted avg       0.71      0.71      0.70       338
#
#
# # Tuning hyper-parameters for recall
#
# Best parameters set found on development set:  {'C': 0.001, 'gamma': 0.01}
# Grid scores on develpment set:
# 0.684 (+/-0.073) for {'C': 0.001, 'gamma': 0.001}
# 0.702 (+/-0.092) for {'C': 0.001, 'gamma': 0.01}
# 0.509 (+/-0.033) for {'C': 0.001, 'gamma': 0.1}
# 0.575 (+/-0.073) for {'C': 0.001, 'gamma': 1}
# 0.500 (+/-0.000) for {'C': 0.001, 'gamma': 10}
# 0.500 (+/-0.000) for {'C': 0.001, 'gamma': 100}
# 0.500 (+/-0.000) for {'C': 0.001, 'gamma': 1000}
# 0.684 (+/-0.073) for {'C': 0.01, 'gamma': 0.001}
# 0.702 (+/-0.092) for {'C': 0.01, 'gamma': 0.01}
# 0.509 (+/-0.033) for {'C': 0.01, 'gamma': 0.1}
# 0.575 (+/-0.073) for {'C': 0.01, 'gamma': 1}
# 0.500 (+/-0.000) for {'C': 0.01, 'gamma': 10}
# 0.500 (+/-0.000) for {'C': 0.01, 'gamma': 100}
# 0.500 (+/-0.000) for {'C': 0.01, 'gamma': 1000}
# 0.680 (+/-0.112) for {'C': 0.1, 'gamma': 0.001}
# 0.698 (+/-0.097) for {'C': 0.1, 'gamma': 0.01}
# 0.509 (+/-0.033) for {'C': 0.1, 'gamma': 0.1}
# 0.575 (+/-0.073) for {'C': 0.1, 'gamma': 1}
# 0.500 (+/-0.000) for {'C': 0.1, 'gamma': 10}
# 0.500 (+/-0.000) for {'C': 0.1, 'gamma': 100}
# 0.500 (+/-0.000) for {'C': 0.1, 'gamma': 1000}
# 0.696 (+/-0.084) for {'C': 1, 'gamma': 0.001}
# 0.687 (+/-0.091) for {'C': 1, 'gamma': 0.01}
# 0.565 (+/-0.082) for {'C': 1, 'gamma': 0.1}
# 0.505 (+/-0.015) for {'C': 1, 'gamma': 1}
# 0.500 (+/-0.000) for {'C': 1, 'gamma': 10}
# 0.500 (+/-0.000) for {'C': 1, 'gamma': 100}
# 0.500 (+/-0.000) for {'C': 1, 'gamma': 1000}
# 0.684 (+/-0.100) for {'C': 10, 'gamma': 0.001}
# 0.662 (+/-0.113) for {'C': 10, 'gamma': 0.01}
# 0.567 (+/-0.099) for {'C': 10, 'gamma': 0.1}
# 0.509 (+/-0.016) for {'C': 10, 'gamma': 1}
# 0.500 (+/-0.000) for {'C': 10, 'gamma': 10}
# 0.500 (+/-0.000) for {'C': 10, 'gamma': 100}
# 0.500 (+/-0.000) for {'C': 10, 'gamma': 1000}
# 0.613 (+/-0.112) for {'C': 100, 'gamma': 0.001}
# 0.662 (+/-0.113) for {'C': 100, 'gamma': 0.01}
# 0.567 (+/-0.099) for {'C': 100, 'gamma': 0.1}
# 0.509 (+/-0.016) for {'C': 100, 'gamma': 1}
# 0.500 (+/-0.000) for {'C': 100, 'gamma': 10}
# 0.500 (+/-0.000) for {'C': 100, 'gamma': 100}
# 0.500 (+/-0.000) for {'C': 100, 'gamma': 1000}
# 0.605 (+/-0.100) for {'C': 1000, 'gamma': 0.001}
# 0.662 (+/-0.113) for {'C': 1000, 'gamma': 0.01}
# 0.567 (+/-0.099) for {'C': 1000, 'gamma': 0.1}
# 0.509 (+/-0.016) for {'C': 1000, 'gamma': 1}
# 0.500 (+/-0.000) for {'C': 1000, 'gamma': 10}
# 0.500 (+/-0.000) for {'C': 1000, 'gamma': 100}
# 0.500 (+/-0.000) for {'C': 1000, 'gamma': 1000}
# Detailed Classification Report:
# the model is trained on the full development set.
# The scores are computed on the full evaluation set.
#               precision    recall  f1-score   support
#
#           -1       0.74      0.74      0.74       173
#            1       0.73      0.72      0.72       165
#
#     accuracy                           0.73       338
#    macro avg       0.73      0.73      0.73       338
# weighted avg       0.73      0.73      0.73       338
#
#
# ******************************** GRID SEARCH FOR: meancurv ******************************
# # Tuning hyper-parameters for precision
#
# Best parameters set found on development set:  {'C': 1, 'gamma': 0.001}
# Grid scores on develpment set:
# 0.576 (+/-0.093) for {'C': 0.001, 'gamma': 0.001}
# 0.591 (+/-0.092) for {'C': 0.001, 'gamma': 0.01}
# 0.620 (+/-0.399) for {'C': 0.001, 'gamma': 0.1}
# 0.542 (+/-0.073) for {'C': 0.001, 'gamma': 1}
# 0.250 (+/-0.000) for {'C': 0.001, 'gamma': 10}
# 0.250 (+/-0.000) for {'C': 0.001, 'gamma': 100}
# 0.250 (+/-0.000) for {'C': 0.001, 'gamma': 1000}
# 0.576 (+/-0.093) for {'C': 0.01, 'gamma': 0.001}
# 0.591 (+/-0.092) for {'C': 0.01, 'gamma': 0.01}
# 0.620 (+/-0.399) for {'C': 0.01, 'gamma': 0.1}
# 0.542 (+/-0.073) for {'C': 0.01, 'gamma': 1}
# 0.250 (+/-0.000) for {'C': 0.01, 'gamma': 10}
# 0.250 (+/-0.000) for {'C': 0.01, 'gamma': 100}
# 0.250 (+/-0.000) for {'C': 0.01, 'gamma': 1000}
# 0.576 (+/-0.093) for {'C': 0.1, 'gamma': 0.001}
# 0.591 (+/-0.092) for {'C': 0.1, 'gamma': 0.01}
# 0.620 (+/-0.399) for {'C': 0.1, 'gamma': 0.1}
# 0.542 (+/-0.073) for {'C': 0.1, 'gamma': 1}
# 0.250 (+/-0.000) for {'C': 0.1, 'gamma': 10}
# 0.250 (+/-0.000) for {'C': 0.1, 'gamma': 100}
# 0.250 (+/-0.000) for {'C': 0.1, 'gamma': 1000}
# 0.656 (+/-0.055) for {'C': 1, 'gamma': 0.001}
# 0.652 (+/-0.073) for {'C': 1, 'gamma': 0.01}
# 0.634 (+/-0.102) for {'C': 1, 'gamma': 0.1}
# 0.451 (+/-0.493) for {'C': 1, 'gamma': 1}
# 0.250 (+/-0.000) for {'C': 1, 'gamma': 10}
# 0.250 (+/-0.000) for {'C': 1, 'gamma': 100}
# 0.250 (+/-0.000) for {'C': 1, 'gamma': 1000}
# 0.646 (+/-0.064) for {'C': 10, 'gamma': 0.001}
# 0.652 (+/-0.038) for {'C': 10, 'gamma': 0.01}
# 0.622 (+/-0.106) for {'C': 10, 'gamma': 0.1}
# 0.629 (+/-0.391) for {'C': 10, 'gamma': 1}
# 0.250 (+/-0.000) for {'C': 10, 'gamma': 10}
# 0.250 (+/-0.000) for {'C': 10, 'gamma': 100}
# 0.250 (+/-0.000) for {'C': 10, 'gamma': 1000}
# 0.615 (+/-0.070) for {'C': 100, 'gamma': 0.001}
# 0.652 (+/-0.038) for {'C': 100, 'gamma': 0.01}
# 0.622 (+/-0.106) for {'C': 100, 'gamma': 0.1}
# 0.629 (+/-0.391) for {'C': 100, 'gamma': 1}
# 0.250 (+/-0.000) for {'C': 100, 'gamma': 10}
# 0.250 (+/-0.000) for {'C': 100, 'gamma': 100}
# 0.250 (+/-0.000) for {'C': 100, 'gamma': 1000}
# 0.615 (+/-0.060) for {'C': 1000, 'gamma': 0.001}
# 0.652 (+/-0.038) for {'C': 1000, 'gamma': 0.01}
# 0.622 (+/-0.106) for {'C': 1000, 'gamma': 0.1}
# 0.629 (+/-0.391) for {'C': 1000, 'gamma': 1}
# 0.250 (+/-0.000) for {'C': 1000, 'gamma': 10}
# 0.250 (+/-0.000) for {'C': 1000, 'gamma': 100}
# 0.250 (+/-0.000) for {'C': 1000, 'gamma': 1000}
# Detailed Classification Report:
# the model is trained on the full development set.
# The scores are computed on the full evaluation set.
#               precision    recall  f1-score   support
#
#           -1       0.68      0.66      0.67       173
#            1       0.66      0.67      0.66       165
#
#     accuracy                           0.67       338
#    macro avg       0.67      0.67      0.67       338
# weighted avg       0.67      0.67      0.67       338
#
#
# # Tuning hyper-parameters for recall
# Best parameters set found on development set:  {'C': 1, 'gamma': 0.001}
# Grid scores on develpment set:
# 0.575 (+/-0.090) for {'C': 0.001, 'gamma': 0.001}
# 0.585 (+/-0.080) for {'C': 0.001, 'gamma': 0.01}
# 0.527 (+/-0.047) for {'C': 0.001, 'gamma': 0.1}
# 0.542 (+/-0.072) for {'C': 0.001, 'gamma': 1}
# 0.500 (+/-0.000) for {'C': 0.001, 'gamma': 10}
# 0.500 (+/-0.000) for {'C': 0.001, 'gamma': 100}
# 0.500 (+/-0.000) for {'C': 0.001, 'gamma': 1000}
# 0.575 (+/-0.090) for {'C': 0.01, 'gamma': 0.001}
# 0.585 (+/-0.080) for {'C': 0.01, 'gamma': 0.01}
# 0.527 (+/-0.047) for {'C': 0.01, 'gamma': 0.1}
# 0.542 (+/-0.072) for {'C': 0.01, 'gamma': 1}
# 0.500 (+/-0.000) for {'C': 0.01, 'gamma': 10}
# 0.500 (+/-0.000) for {'C': 0.01, 'gamma': 100}
# 0.500 (+/-0.000) for {'C': 0.01, 'gamma': 1000}
# 0.575 (+/-0.090) for {'C': 0.1, 'gamma': 0.001}
# 0.585 (+/-0.080) for {'C': 0.1, 'gamma': 0.01}
# 0.527 (+/-0.047) for {'C': 0.1, 'gamma': 0.1}
# 0.542 (+/-0.072) for {'C': 0.1, 'gamma': 1}
# 0.500 (+/-0.000) for {'C': 0.1, 'gamma': 10}
# 0.500 (+/-0.000) for {'C': 0.1, 'gamma': 100}
# 0.500 (+/-0.000) for {'C': 0.1, 'gamma': 1000}
# 0.653 (+/-0.056) for {'C': 1, 'gamma': 0.001}
# 0.651 (+/-0.073) for {'C': 1, 'gamma': 0.01}
# 0.605 (+/-0.087) for {'C': 1, 'gamma': 0.1}
# 0.505 (+/-0.015) for {'C': 1, 'gamma': 1}
# 0.500 (+/-0.000) for {'C': 1, 'gamma': 10}
# 0.500 (+/-0.000) for {'C': 1, 'gamma': 100}
# 0.500 (+/-0.000) for {'C': 1, 'gamma': 1000}
# 0.645 (+/-0.065) for {'C': 10, 'gamma': 0.001}
# 0.651 (+/-0.037) for {'C': 10, 'gamma': 0.01}
# 0.600 (+/-0.091) for {'C': 10, 'gamma': 0.1}
# 0.515 (+/-0.019) for {'C': 10, 'gamma': 1}
# 0.500 (+/-0.000) for {'C': 10, 'gamma': 10}
# 0.500 (+/-0.000) for {'C': 10, 'gamma': 100}
# 0.500 (+/-0.000) for {'C': 10, 'gamma': 1000}
# 0.615 (+/-0.071) for {'C': 100, 'gamma': 0.001}
# 0.651 (+/-0.037) for {'C': 100, 'gamma': 0.01}
# 0.600 (+/-0.091) for {'C': 100, 'gamma': 0.1}
# 0.515 (+/-0.019) for {'C': 100, 'gamma': 1}
# 0.500 (+/-0.000) for {'C': 100, 'gamma': 10}
# 0.500 (+/-0.000) for {'C': 100, 'gamma': 100}
# 0.500 (+/-0.000) for {'C': 100, 'gamma': 1000}
# 0.615 (+/-0.060) for {'C': 1000, 'gamma': 0.001}
# 0.651 (+/-0.037) for {'C': 1000, 'gamma': 0.01}
# 0.600 (+/-0.091) for {'C': 1000, 'gamma': 0.1}
# 0.515 (+/-0.019) for {'C': 1000, 'gamma': 1}
# 0.500 (+/-0.000) for {'C': 1000, 'gamma': 10}
# 0.500 (+/-0.000) for {'C': 1000, 'gamma': 100}
# 0.500 (+/-0.000) for {'C': 1000, 'gamma': 1000}
# Detailed Classification Report:
# the model is trained on the full development set.
# The scores are computed on the full evaluation set.
#               precision    recall  f1-score   support
#
#           -1       0.68      0.66      0.67       173
#            1       0.66      0.67      0.66       165
#
#     accuracy                           0.67       338
#    macro avg       0.67      0.67      0.67       338
# weighted avg       0.67      0.67      0.67       338
#
#
# ******************************** GRID SEARCH FOR: thickness ******************************
# # Tuning hyper-parameters for precision
#
# Best parameters set found on development set:  {'C': 1, 'gamma': 0.001}
# Grid scores on develpment set:
# 0.603 (+/-0.087) for {'C': 0.001, 'gamma': 0.001}
# 0.607 (+/-0.083) for {'C': 0.001, 'gamma': 0.01}
# 0.511 (+/-0.322) for {'C': 0.001, 'gamma': 0.1}
# 0.558 (+/-0.141) for {'C': 0.001, 'gamma': 1}
# 0.250 (+/-0.000) for {'C': 0.001, 'gamma': 10}
# 0.250 (+/-0.000) for {'C': 0.001, 'gamma': 100}
# 0.250 (+/-0.000) for {'C': 0.001, 'gamma': 1000}
# 0.603 (+/-0.087) for {'C': 0.01, 'gamma': 0.001}
# 0.607 (+/-0.083) for {'C': 0.01, 'gamma': 0.01}
# 0.511 (+/-0.322) for {'C': 0.01, 'gamma': 0.1}
# 0.558 (+/-0.141) for {'C': 0.01, 'gamma': 1}
# 0.250 (+/-0.000) for {'C': 0.01, 'gamma': 10}
# 0.250 (+/-0.000) for {'C': 0.01, 'gamma': 100}
# 0.250 (+/-0.000) for {'C': 0.01, 'gamma': 1000}
# 0.603 (+/-0.087) for {'C': 0.1, 'gamma': 0.001}
# 0.607 (+/-0.083) for {'C': 0.1, 'gamma': 0.01}
# 0.511 (+/-0.322) for {'C': 0.1, 'gamma': 0.1}
# 0.558 (+/-0.141) for {'C': 0.1, 'gamma': 1}
# 0.250 (+/-0.000) for {'C': 0.1, 'gamma': 10}
# 0.250 (+/-0.000) for {'C': 0.1, 'gamma': 100}
# 0.250 (+/-0.000) for {'C': 0.1, 'gamma': 1000}
# 0.665 (+/-0.040) for {'C': 1, 'gamma': 0.001}
# 0.650 (+/-0.048) for {'C': 1, 'gamma': 0.01}
# 0.556 (+/-0.069) for {'C': 1, 'gamma': 0.1}
# 0.451 (+/-0.492) for {'C': 1, 'gamma': 1}
# 0.250 (+/-0.000) for {'C': 1, 'gamma': 10}
# 0.250 (+/-0.000) for {'C': 1, 'gamma': 100}
# 0.250 (+/-0.000) for {'C': 1, 'gamma': 1000}
# 0.645 (+/-0.045) for {'C': 10, 'gamma': 0.001}
# 0.664 (+/-0.072) for {'C': 10, 'gamma': 0.01}
# 0.562 (+/-0.055) for {'C': 10, 'gamma': 0.1}
# 0.601 (+/-0.404) for {'C': 10, 'gamma': 1}
# 0.250 (+/-0.000) for {'C': 10, 'gamma': 10}
# 0.250 (+/-0.000) for {'C': 10, 'gamma': 100}
# 0.250 (+/-0.000) for {'C': 10, 'gamma': 1000}
# 0.634 (+/-0.079) for {'C': 100, 'gamma': 0.001}
# 0.664 (+/-0.072) for {'C': 100, 'gamma': 0.01}
# 0.562 (+/-0.055) for {'C': 100, 'gamma': 0.1}
# 0.601 (+/-0.404) for {'C': 100, 'gamma': 1}
# 0.250 (+/-0.000) for {'C': 100, 'gamma': 10}
# 0.250 (+/-0.000) for {'C': 100, 'gamma': 100}
# 0.250 (+/-0.000) for {'C': 100, 'gamma': 1000}
# 0.639 (+/-0.081) for {'C': 1000, 'gamma': 0.001}
# 0.664 (+/-0.072) for {'C': 1000, 'gamma': 0.01}
# 0.562 (+/-0.055) for {'C': 1000, 'gamma': 0.1}
# 0.601 (+/-0.404) for {'C': 1000, 'gamma': 1}
# 0.250 (+/-0.000) for {'C': 1000, 'gamma': 10}
# 0.250 (+/-0.000) for {'C': 1000, 'gamma': 100}
# 0.250 (+/-0.000) for {'C': 1000, 'gamma': 1000}
# Detailed Classification Report:
# the model is trained on the full development set.
# The scores are computed on the full evaluation set.
#               precision    recall  f1-score   support
#
#           -1       0.79      0.75      0.77       173
#            1       0.75      0.79      0.77       165
#
#     accuracy                           0.77       338
#    macro avg       0.77      0.77      0.77       338
# weighted avg       0.77      0.77      0.77       338
#
#
# # Tuning hyper-parameters for recall
#
# Best parameters set found on development set:  {'C': 1, 'gamma': 0.001}
# Grid scores on develpment set:
# 0.596 (+/-0.075) for {'C': 0.001, 'gamma': 0.001}
# 0.605 (+/-0.083) for {'C': 0.001, 'gamma': 0.01}
# 0.507 (+/-0.031) for {'C': 0.001, 'gamma': 0.1}
# 0.558 (+/-0.140) for {'C': 0.001, 'gamma': 1}
# 0.500 (+/-0.000) for {'C': 0.001, 'gamma': 10}
# 0.500 (+/-0.000) for {'C': 0.001, 'gamma': 100}
# 0.500 (+/-0.000) for {'C': 0.001, 'gamma': 1000}
# 0.596 (+/-0.075) for {'C': 0.01, 'gamma': 0.001}
# 0.605 (+/-0.083) for {'C': 0.01, 'gamma': 0.01}
# 0.507 (+/-0.031) for {'C': 0.01, 'gamma': 0.1}
# 0.558 (+/-0.140) for {'C': 0.01, 'gamma': 1}
# 0.500 (+/-0.000) for {'C': 0.01, 'gamma': 10}
# 0.500 (+/-0.000) for {'C': 0.01, 'gamma': 100}
# 0.500 (+/-0.000) for {'C': 0.01, 'gamma': 1000}
# 0.596 (+/-0.075) for {'C': 0.1, 'gamma': 0.001}
# 0.605 (+/-0.083) for {'C': 0.1, 'gamma': 0.01}
# 0.507 (+/-0.031) for {'C': 0.1, 'gamma': 0.1}
# 0.558 (+/-0.140) for {'C': 0.1, 'gamma': 1}
# 0.500 (+/-0.000) for {'C': 0.1, 'gamma': 10}
# 0.500 (+/-0.000) for {'C': 0.1, 'gamma': 100}
# 0.500 (+/-0.000) for {'C': 0.1, 'gamma': 1000}
# 0.664 (+/-0.038) for {'C': 1, 'gamma': 0.001}
# 0.649 (+/-0.047) for {'C': 1, 'gamma': 0.01}
# 0.547 (+/-0.062) for {'C': 1, 'gamma': 0.1}
# 0.504 (+/-0.009) for {'C': 1, 'gamma': 1}
# 0.500 (+/-0.000) for {'C': 1, 'gamma': 10}
# 0.500 (+/-0.000) for {'C': 1, 'gamma': 100}
# 0.500 (+/-0.000) for {'C': 1, 'gamma': 1000}
# 0.644 (+/-0.044) for {'C': 10, 'gamma': 0.001}
# 0.662 (+/-0.071) for {'C': 10, 'gamma': 0.01}
# 0.551 (+/-0.048) for {'C': 10, 'gamma': 0.1}
# 0.504 (+/-0.015) for {'C': 10, 'gamma': 1}
# 0.500 (+/-0.000) for {'C': 10, 'gamma': 10}
# 0.500 (+/-0.000) for {'C': 10, 'gamma': 100}
# 0.500 (+/-0.000) for {'C': 10, 'gamma': 1000}
# 0.633 (+/-0.080) for {'C': 100, 'gamma': 0.001}
# 0.662 (+/-0.071) for {'C': 100, 'gamma': 0.01}
# 0.551 (+/-0.048) for {'C': 100, 'gamma': 0.1}
# 0.504 (+/-0.015) for {'C': 100, 'gamma': 1}
# 0.500 (+/-0.000) for {'C': 100, 'gamma': 10}
# 0.500 (+/-0.000) for {'C': 100, 'gamma': 100}
# 0.500 (+/-0.000) for {'C': 100, 'gamma': 1000}
# 0.638 (+/-0.082) for {'C': 1000, 'gamma': 0.001}
# 0.662 (+/-0.071) for {'C': 1000, 'gamma': 0.01}
# 0.551 (+/-0.048) for {'C': 1000, 'gamma': 0.1}
# 0.504 (+/-0.015) for {'C': 1000, 'gamma': 1}
# 0.500 (+/-0.000) for {'C': 1000, 'gamma': 10}
# 0.500 (+/-0.000) for {'C': 1000, 'gamma': 100}
# 0.500 (+/-0.000) for {'C': 1000, 'gamma': 1000}
# Detailed Classification Report:
# the model is trained on the full development set.
# The scores are computed on the full evaluation set.
#               precision    recall  f1-score   support
#
#           -1       0.79      0.75      0.77       173
#            1       0.75      0.79      0.77       165
#
#     accuracy                           0.77       338
#    macro avg       0.77      0.77      0.77       338
# weighted avg       0.77      0.77      0.77       338
#
#
# ******************************** GRID SEARCH FOR: volume ******************************
# # Tuning hyper-parameters for precision
# Best parameters set found on development set:  {'C': 1, 'gamma': 0.001}
# Grid scores on develpment set:
# 0.713 (+/-0.108) for {'C': 0.001, 'gamma': 0.001}
# 0.689 (+/-0.096) for {'C': 0.001, 'gamma': 0.01}
# 0.512 (+/-0.119) for {'C': 0.001, 'gamma': 0.1}
# 0.609 (+/-0.124) for {'C': 0.001, 'gamma': 1}
# 0.250 (+/-0.000) for {'C': 0.001, 'gamma': 10}
# 0.250 (+/-0.000) for {'C': 0.001, 'gamma': 100}
# 0.250 (+/-0.000) for {'C': 0.001, 'gamma': 1000}
# 0.713 (+/-0.108) for {'C': 0.01, 'gamma': 0.001}
# 0.689 (+/-0.096) for {'C': 0.01, 'gamma': 0.01}
# 0.512 (+/-0.119) for {'C': 0.01, 'gamma': 0.1}
# 0.609 (+/-0.124) for {'C': 0.01, 'gamma': 1}
# 0.250 (+/-0.000) for {'C': 0.01, 'gamma': 10}
# 0.250 (+/-0.000) for {'C': 0.01, 'gamma': 100}
# 0.250 (+/-0.000) for {'C': 0.01, 'gamma': 1000}
# 0.696 (+/-0.106) for {'C': 0.1, 'gamma': 0.001}
# 0.691 (+/-0.095) for {'C': 0.1, 'gamma': 0.01}
# 0.512 (+/-0.119) for {'C': 0.1, 'gamma': 0.1}
# 0.609 (+/-0.124) for {'C': 0.1, 'gamma': 1}
# 0.250 (+/-0.000) for {'C': 0.1, 'gamma': 10}
# 0.250 (+/-0.000) for {'C': 0.1, 'gamma': 100}
# 0.250 (+/-0.000) for {'C': 0.1, 'gamma': 1000}
# 0.717 (+/-0.106) for {'C': 1, 'gamma': 0.001}
# 0.705 (+/-0.110) for {'C': 1, 'gamma': 0.01}
# 0.610 (+/-0.063) for {'C': 1, 'gamma': 0.1}
# 0.367 (+/-0.292) for {'C': 1, 'gamma': 1}
# 0.250 (+/-0.000) for {'C': 1, 'gamma': 10}
# 0.250 (+/-0.000) for {'C': 1, 'gamma': 100}
# 0.250 (+/-0.000) for {'C': 1, 'gamma': 1000}
# 0.683 (+/-0.060) for {'C': 10, 'gamma': 0.001}
# 0.668 (+/-0.101) for {'C': 10, 'gamma': 0.01}
# 0.612 (+/-0.053) for {'C': 10, 'gamma': 0.1}
# 0.384 (+/-0.329) for {'C': 10, 'gamma': 1}
# 0.250 (+/-0.000) for {'C': 10, 'gamma': 10}
# 0.250 (+/-0.000) for {'C': 10, 'gamma': 100}
# 0.250 (+/-0.000) for {'C': 10, 'gamma': 1000}
# 0.635 (+/-0.050) for {'C': 100, 'gamma': 0.001}
# 0.668 (+/-0.101) for {'C': 100, 'gamma': 0.01}
# 0.612 (+/-0.053) for {'C': 100, 'gamma': 0.1}
# 0.384 (+/-0.329) for {'C': 100, 'gamma': 1}
# 0.250 (+/-0.000) for {'C': 100, 'gamma': 10}
# 0.250 (+/-0.000) for {'C': 100, 'gamma': 100}
# 0.250 (+/-0.000) for {'C': 100, 'gamma': 1000}
# 0.630 (+/-0.063) for {'C': 1000, 'gamma': 0.001}
# 0.668 (+/-0.101) for {'C': 1000, 'gamma': 0.01}
# 0.612 (+/-0.053) for {'C': 1000, 'gamma': 0.1}
# 0.384 (+/-0.329) for {'C': 1000, 'gamma': 1}
# 0.250 (+/-0.000) for {'C': 1000, 'gamma': 10}
# 0.250 (+/-0.000) for {'C': 1000, 'gamma': 100}
# 0.250 (+/-0.000) for {'C': 1000, 'gamma': 1000}
# Detailed Classification Report:
# the model is trained on the full development set.
# The scores are computed on the full evaluation set.
#               precision    recall  f1-score   support
#
#           -1       0.72      0.79      0.75       173
#            1       0.76      0.68      0.72       165
#
#     accuracy                           0.74       338
#    macro avg       0.74      0.74      0.74       338
# weighted avg       0.74      0.74      0.74       338
#
#
# # Tuning hyper-parameters for recall
#
# Best parameters set found on development set:  {'C': 1, 'gamma': 0.001}
# Grid scores on develpment set:
# 0.698 (+/-0.099) for {'C': 0.001, 'gamma': 0.001}
# 0.687 (+/-0.096) for {'C': 0.001, 'gamma': 0.01}
# 0.507 (+/-0.031) for {'C': 0.001, 'gamma': 0.1}
# 0.609 (+/-0.124) for {'C': 0.001, 'gamma': 1}
# 0.500 (+/-0.000) for {'C': 0.001, 'gamma': 10}
# 0.500 (+/-0.000) for {'C': 0.001, 'gamma': 100}
# 0.500 (+/-0.000) for {'C': 0.001, 'gamma': 1000}
# 0.698 (+/-0.099) for {'C': 0.01, 'gamma': 0.001}
# 0.687 (+/-0.096) for {'C': 0.01, 'gamma': 0.01}
# 0.507 (+/-0.031) for {'C': 0.01, 'gamma': 0.1}
# 0.609 (+/-0.124) for {'C': 0.01, 'gamma': 1}
# 0.500 (+/-0.000) for {'C': 0.01, 'gamma': 10}
# 0.500 (+/-0.000) for {'C': 0.01, 'gamma': 100}
# 0.500 (+/-0.000) for {'C': 0.01, 'gamma': 1000}
# 0.691 (+/-0.103) for {'C': 0.1, 'gamma': 0.001}
# 0.689 (+/-0.094) for {'C': 0.1, 'gamma': 0.01}
# 0.507 (+/-0.031) for {'C': 0.1, 'gamma': 0.1}
# 0.609 (+/-0.124) for {'C': 0.1, 'gamma': 1}
# 0.500 (+/-0.000) for {'C': 0.1, 'gamma': 10}
# 0.500 (+/-0.000) for {'C': 0.1, 'gamma': 100}
# 0.500 (+/-0.000) for {'C': 0.1, 'gamma': 1000}
# 0.711 (+/-0.100) for {'C': 1, 'gamma': 0.001}
# 0.700 (+/-0.105) for {'C': 1, 'gamma': 0.01}
# 0.575 (+/-0.048) for {'C': 1, 'gamma': 0.1}
# 0.502 (+/-0.007) for {'C': 1, 'gamma': 1}
# 0.500 (+/-0.000) for {'C': 1, 'gamma': 10}
# 0.500 (+/-0.000) for {'C': 1, 'gamma': 100}
# 0.500 (+/-0.000) for {'C': 1, 'gamma': 1000}
# 0.680 (+/-0.056) for {'C': 10, 'gamma': 0.001}
# 0.667 (+/-0.101) for {'C': 10, 'gamma': 0.01}
# 0.576 (+/-0.042) for {'C': 10, 'gamma': 0.1}
# 0.504 (+/-0.009) for {'C': 10, 'gamma': 1}
# 0.500 (+/-0.000) for {'C': 10, 'gamma': 10}
# 0.500 (+/-0.000) for {'C': 10, 'gamma': 100}
# 0.500 (+/-0.000) for {'C': 10, 'gamma': 1000}
# 0.635 (+/-0.049) for {'C': 100, 'gamma': 0.001}
# 0.667 (+/-0.101) for {'C': 100, 'gamma': 0.01}
# 0.576 (+/-0.042) for {'C': 100, 'gamma': 0.1}
# 0.504 (+/-0.009) for {'C': 100, 'gamma': 1}
# 0.500 (+/-0.000) for {'C': 100, 'gamma': 10}
# 0.500 (+/-0.000) for {'C': 100, 'gamma': 100}
# 0.500 (+/-0.000) for {'C': 100, 'gamma': 1000}
# 0.629 (+/-0.063) for {'C': 1000, 'gamma': 0.001}
# 0.667 (+/-0.101) for {'C': 1000, 'gamma': 0.01}
# 0.576 (+/-0.042) for {'C': 1000, 'gamma': 0.1}
# 0.504 (+/-0.009) for {'C': 1000, 'gamma': 1}
# 0.500 (+/-0.000) for {'C': 1000, 'gamma': 10}
# 0.500 (+/-0.000) for {'C': 1000, 'gamma': 100}
# 0.500 (+/-0.000) for {'C': 1000, 'gamma': 1000}
# Detailed Classification Report:
# the model is trained on the full development set.
# The scores are computed on the full evaluation set.
#               precision    recall  f1-score   support
#
#           -1       0.72      0.79      0.75       173
#            1       0.76      0.68      0.72       165
#
#     accuracy                           0.74       338
#    macro avg       0.74      0.74      0.74       338
# weighted avg       0.74      0.74      0.74       338

# %% [markdown]
# # best grid search is the second

# %%
best_configuration
# Out:
# [{'name': 'area', 'data': {'C': 0.1, 'gamma': 0.0001, 'kernel': 'rbf'}},
#  {'name': 'meancurv', 'data': {'C': 10, 'gamma': 0.0001, 'kernel': 'rbf'}},
#  {'name': 'thickness', 'data': {'C': 1, 'gamma': 0.001, 'kernel': 'rbf'}},
#  {'name': 'volume', 'data': {'C': 1, 'gamma': 0.001, 'kernel': 'rbf'}}]

# %%
best_configuration_2
# Out:
# [{'name': 'area', 'data': {'C': 1, 'gamma': 0.001}},
#  {'name': 'meancurv', 'data': {'C': 1, 'gamma': 0.001}},
#  {'name': 'thickness', 'data': {'C': 1, 'gamma': 0.001}},
#  {'name': 'volume', 'data': {'C': 1, 'gamma': 0.001}}]

# %%
clfs = []
for feature, feature_tr, feature_val in zip (best_configuration_2, df_X_tr, df_X_val):
    c = feature['data']['C']
    gamma = feature['data']['gamma']
    data_name = feature_tr['name']
    df_train = feature_tr['data']
    df_val = feature_val['data']
    
    # create and train
    clf = svm.SVC(kernel='rbf', C = c, gamma = gamma)
    clf.fit(df_train, df_y_train)
    
    #checking the score 
    print("Score for " + data_name + ": ", clf.score(df_val,df_y_val))
    
    #saving the classificator
    joblib.dump(clf, 'output/SVM Non Linear - Optimal - ' + data_name +'.pkl')
    
    #saving an instance  of the clf 
    clfs.append({'name' : data_name, 'data' : clf})
# Out:
# /home/students/anaconda3/lib/python3.7/site-packages/sklearn/utils/validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/students/anaconda3/lib/python3.7/site-packages/sklearn/utils/validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Score for area:  0.7071005917159763
# Score for meancurv:  0.6686390532544378
# /home/students/anaconda3/lib/python3.7/site-packages/sklearn/utils/validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/students/anaconda3/lib/python3.7/site-packages/sklearn/utils/validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Score for thickness:  0.772189349112426
# Score for volume:  0.7366863905325444

# %% [markdown]
# # Confusion Matrix

# %%
def plot_confusion_matrix(cm, classes, normalize = False,
                         title = 'Confusion matrix', cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting 'normalie = True'
    """
    
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[: np.newaxis]
        print("Normalized confusion matrix")
    else:
        print("Confusion matrix, without normalization")
    
    print(cm)
    
    plt.imshow(cm, interpolation='nearest', cmap = cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation = 45)
    plt.yticks(tick_marks, classes)
    
    # '.2f' limits float to two decimal point
    # 'd' number decimal
    fmt = '.2f' if normalize else 'd' 
    
    thresh = cm.max() / 2
    
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format (cm[i,j], fmt), horizontalalignment = "center", verticalalignment = "center",
                 color = "white" if cm[i,j] > thresh +10 else "black")
    
    plt.tight_layout()
    plt.ylabel('true label')
    plt.xlabel('Predicted label')

# %%
for feature, clf in zip(df_X_val, clfs):
    data = feature['data']
    name = feature['name']
    clf_data = clf['data']
    
    print("******************************** CONFUSION MATRI FOR: " + name + " ******************************")
    
    # Compute Confusion matrix
    cnf_matrix = confusion_matrix(df_y_val['class'], clf_data.predict(data))
    np.set_printoptions(precision=2)

    # Plot non-normalied confusion matrix
    plt.figure()
    plot_confusion_matrix(cnf_matrix, classes=['Weak', 'Strong'],
                         title='confusion matrix, without normalization')

    # Plot normalized confusion matrix
    plt.figure()
    plot_confusion_matrix(cnf_matrix, classes=['Weak', 'Strong'], normalize=True,
                         title='normalized confusion matrix')
    plt.show()
# Out:
# ******************************** CONFUSION MATRI FOR: area ******************************
# Confusion matrix, without normalization
# [[138  35]
#  [ 64 101]]
# Normalized confusion matrix
# [[0.8  0.21]
#  [0.37 0.61]]
# ******************************** CONFUSION MATRI FOR: meancurv ******************************
# Confusion matrix, without normalization
# [[115  58]
#  [ 54 111]]
# Normalized confusion matrix
# [[0.66 0.35]
#  [0.31 0.67]]
# ******************************** CONFUSION MATRI FOR: thickness ******************************
# Confusion matrix, without normalization
# [[130  43]
#  [ 34 131]]
# Normalized confusion matrix
# [[0.75 0.26]
#  [0.2  0.79]]
# ******************************** CONFUSION MATRI FOR: volume ******************************
# Confusion matrix, without normalization
# [[137  36]
#  [ 53 112]]
# Normalized confusion matrix
# [[0.79 0.22]
#  [0.31 0.68]]
